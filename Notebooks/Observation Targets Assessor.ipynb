# %% [markdown]
# # Observation Targets Assessor
# This notebook aims to injest a list of source descriptions and observation criteria from the STM effort, applying appropriate metric tools to assess against the critera for a list of mission concept descriptions.
#
# To run this on Google Colab:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnGBaker/GWI-metrics/blob/main/Notebooks/binaryResolutionSources.ipynb)
#
# ### Some basic setup

# %%
if 'google.colab' in str(get_ipython()):
    # !git clone https://github.com/JohnGBaker/GWI-metrics.git
    src='GWI-metrics/src/'
else:
    src='../src/'
# !mkdir -p '../plots/'

# Import
import os
from datetime import date
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append(src)
import constants
import metrics
import sources
import concepts
import subsystems
import background
import pandas as pd
from glob import glob
import re
from astropy.coordinates import Angle
from astropy.cosmology import WMAP9 as cosmo
from astropy import units as u

# %% [markdown]
# ### Define the set of concepts
# Here we load in a set of the pre-defined concepts, or you can define your own

# %%
missionNames = (
    'LISACBE',
    'LISASciRDv1',
    'TwinLISA',
    'LISAGrande',
    'LISAU',
    'GoBIGLISA',
    'ALIA',
    'ALIAlowL')
missions=[concepts.menu[mission] for mission in missionNames]

for mission in missions:
    mission=background.add2model(mission)
#model = concepts.LISACBE.copy()
#modelName = model.get('label')
#model = background.add2model(model)     # add galactic background model

# %% [markdown]
# ### Load the observation target data
# Load information about the target sources and the observation quality targets from the STM.
# The data are from https://nasa.sharepoint.com/:x:/t/GravitationalWaveImager/EaaeMC7L-2NJpFCQloYbSnoBDZag_cvFWR5_BjRoFAD6Tw?e=uWr4mU

# %%
datadir='../Data/'
files=glob(datadir+'ObservationObjectives*.csv')
files.sort(key=os.path.getmtime)
file=files[0]
print('Observation targets file is:',file)
#Read file
df=pd.read_csv(file,header=1)
print(len(df),'rows read from file.')
if True:
    #Drop empty rows
    for i,row in df.iterrows():
        if row.isnull().all():
            df=df.drop(i)
    #Fill empties in first column with values above
    val=float('nan')
    col='Source class'
    for i,row in df.iterrows():
        if row.isnull()[col]:
            df.loc[i,col]=val
        else:
            val=df.loc[i,col]
#Drop rows without a labeled objective
for i,row in df.iterrows():
    if row.isnull()['provisional POC label']:
        df=df.drop(i)
print(len(df),'rows with a potential observation label.')
#Fill empties with value above
if True:
    for columnName, columnData in df.iteritems():
        val=float('nan')
        nulls=columnData.isnull()
        for i,row in df.iterrows():
            if nulls[i]:
                df.loc[i,columnName]=val
            else:
                val=df.loc[i,columnName]
#derive masses
if True:
    col=2
    df['m1']=float('nan')
    df['m2']=float('nan')
    for i,row in df.iterrows():
        txt=row.iloc[col]
        mtxt=re.search('\s*Msun\s*\+\s*.*Msun',txt)
        #print('::',mtxt)
        mtxt=re.search('(\d+\.*\d*[eE]*[\+-]*\d*)\s*M[Ss]un\s*\+\s*(\d+\.*\d*[eE]*[\+-]*\d*)\s*M[Ss]un',txt)
        #print(':',mtxt)
        m1=None
        if mtxt is not None: 
            try:
                m1=float(mtxt[1])
                #print(m1)
                m2=float(mtxt[2])
                #print(m2)
            except: 
                pass
        if m1 is None:
            df=df.drop(i)
        else:
            df.loc[i,'m1']=m1
            df.loc[i,'m2']=m2
    print(len(df),'rows with masses.')
#derive redshifts/distances
if True:
    col=3
    df['z']=float('nan')
    df['dist']=float('nan')
    for i,row in df.iterrows():
        txt=row.iloc[col]
        ztxt=re.search('z\s*=\s*(\d+\.*\d*[eE]*[\+-]*\d*)',txt)
        z=None
        if ztxt is not None: 
            try:
                z=float(ztxt[1])
                dist=cosmo.luminosity_distance(z).to(u.kpc).value
            except: 
                pass
        if z is None:
            df=df.drop(i)
        else:
            df.loc[i,'z']=z
            df.loc[i,'dist']=dist
    print(len(df),'rows with redshift.')
#derive timecuts
if True:
    col=4
    df['timecut']=float('nan')
    for i,row in df.iterrows():
        txt=row.iloc[col]
        ztxt=re.search('(.*)\s+(before|<)\s+merger',txt)
        z=None
        if ztxt is not None:
            try:
                ztxt=ztxt[1]
                if ztxt=='month to week': z=15
                elif ztxt=='year to month': z=180
            except: 
                pass
        df.loc[i,'timecut']=z
#derive SNRs
if True:
    col=4
    df['SNR']=float('nan')
    for i,row in df.iterrows():
        txt=row.iloc[col]
        ztxt=re.search('SNR\s*=\s*(\d+\.*\d*[eE]*[\+-]*\d*)',txt)
        z=None
        if ztxt is not None: 
            try:
                z=float(ztxt[1])
            except: 
                pass
        df.loc[i,'SNR']=z
#prep CW sources
if True:
    col=0
    df['CW']=False
    df['f0']=float('nan')
    for i,row in df.iterrows():
        txt=row.iloc[col]
        if 'Persistent' in txt: 
            df.loc[i,'CW']=True
            #Also need to f0 (or separation)
            txt=row['freq']
            try:
                ftxt=re.search('(\d+\.*\d*[eE]*[\+-]*\d*)\s+Hz',txt)[1]
                f0=float(ftxt)
                df.loc[i,'f0']=f0
            except:
                print('Failed to get freq from txt "'+txt+'"')
                df=df.drop(i)
#process angular precision
if True:
    col=6
    df['resolution']=float('nan')
    for i,row in df.iterrows():
        txt=row.iloc[col]
        z=None
        #print(txt)
        try:
            #print(Angle(txt))
            z=Angle(txt).arcsecond
        except: 
            pass
        df.loc[i,'resolution']=z
#Drop cases with neither angular precision requirement nor SNR
for i,row in df.iterrows():
    if np.isnan(row['resolution']) and np.isnan(row['SNR']):df=df.drop(i)
print(len(df),'rows with constraints.')        
display(df)
# Out:
# Observation targets file is: ../Data/ObservationObjectives-9-May-22.csv
# 110 rows read from file.
# 54 rows with a potential observation label.
# 51 rows with masses.
# 48 rows with redshift.
# 42 rows with constraints.
#                    Source class  Source label   Source specification  \
# 1      1. Stellar-scale mergers     NS binary    1.5 MSun + 1.5 MSun
# 2      1. Stellar-scale mergers     NS binary    1.5 MSun + 1.5 MSun
# 3      1. Stellar-scale mergers     NS binary    1.5 MSun + 1.5 MSun
# 4      1. Stellar-scale mergers     NS binary    1.5 MSun + 1.5 MSun
# 6      1. Stellar-scale mergers  NS-BH binary     1.5 MSun + 10 MSun
# 8      1. Stellar-scale mergers     BH binary      30 MSun + 30 MSun
# 10     1. Stellar-scale mergers     BH binary      30 MSun + 30 MSun
# 11     1. Stellar-scale mergers     BH binary      30 MSun + 30 MSun
# 12     1. Stellar-scale mergers     BH binary      30 MSun + 30 MSun
# 16                       2.MBHB    MBH binary    1e6 MSun + 1e6 MSun
# 17                       2.MBHB    MBH binary    1e6 MSun + 1e6 MSun
# 18                       2.MBHB    MBH binary    1e6 MSun + 1e6 MSun
# 19                       2.MBHB    MBH binary    1e6 MSun + 1e6 MSun
# 21                       2.MBHB    MBH binary   5e5 MSun + 5e5 MSun,
# 23                       2.MBHB    MBH binary   5e5 MSun + 5e5 MSun,
# 25                       3.EMRI   SMBH + IMBH    1e2 MSun + 1e8 MSun
# 26                       3.EMRI   SMBH + SOBH      1 MSun + 1e7 MSun
# 27                       3.EMRI   SMBH + SOBH      1 MSun + 1e7 MSun
# 28                       3.EMRI   SMBH + SOBH      10MSun +  5e5Msun
# 29                       3.EMRI   SMBH + SOBH      10MSun +  5e5Msun
# 30                       3.EMRI   SMBH + SOBH      10MSun +  5e5Msun
# 31                       3.EMRI   SMBH + SOBH      10MSun +  5e5Msun
# 32                       3.EMRI   SMBH + SOBH      10MSun +  5e5Msun
# 33                       3.EMRI     SMBH + WD    5e5 Msun + 0.6 Msun
# 36  4.Persistent stellar binary     WD binary    0.6 MSun + 0.6 MSun
# 37  4.Persistent stellar binary     WD binary    0.6 MSun + 0.6 MSun
# 38  4.Persistent stellar binary     WD binary    0.6 MSun + 0.6 MSun
# 39  4.Persistent stellar binary     WD binary    0.6 MSun + 0.6 MSun
# 45                      5. IMRI   IMBH + SOBH     100 MSun + 10 MSun
# 46                      5. IMRI   IMBH + SOBH     100 MSun + 10 MSun
# 47                      5. IMRI   IMBH + SOBH     100 MSun + 10 MSun
# 48                      5. IMRI   IMBH + SOBH     100 MSun + 10 MSun
# 49                      5. IMRI   IMBH + SOBH    2000 MSun + 40 MSun
# 50                      5. IMRI   IMBH + SOBH    2000 MSun + 40 MSun
# 53                      5. IMRI   IMBH + IMBH   1000 MSun + 100 MSun
# 54                      5. IMRI   IMBH + IMBH   1000 MSun + 100 MSun
# 56                      5. IMRI   IMBH + IMBH  1000 MSun + 1000 MSun
# 57                      5. IMRI   IMBH + IMBH  1000 MSun + 1000 MSun
# 59                      5. IMRI     IMBH + WD   10^3 MSun + 0.8 Msun
# 60                      5. IMRI     IMBH + WD   10^3 MSun + 0.8 Msun
# 61                      5. IMRI   IMBH + SOBH      5e3 Msun + 1 Msun
# 62                      5. IMRI    MBH + IMBH    1e6 MSun + 1e3 MSun
#
#    Distance/redshift (dL in kpc)  \
# 1          z = 0.05; dL = 2.30e5
# 2           z = 1.0; dL = 6.79e6
# 3            z = 20; dL = 2.31e8
# 4            z = 10; dL = 1.07e8
# 6           z = 0.2; dL = 1.01e6
# 8           z = 0.2; dL = 1.01e6
# 10          z = 1.0; dL = 6.79e6
# 11           z = 20; dL = 2.31e8
# 12           z = 10; dL = 1.07e8
# 16          z = 1.0; dL = 6.79e6
# 17          z = 1.0; dL = 6.79e6
# 18           z = 20; dL = 2.31e8
# 19           z = 10; dL = 1.07e8
# 21              z=2; dL = 1.59e7
# 23              z=2; dL = 1.59e7
# 25          z = 0.5; dL = 2.92e6
# 26            z=0.2; dL = 1.01e6
# 27            z=0.2; dL = 1.01e6
# 28            z=1.5; dL = 1.22e7
# 29            z=1.5; dL = 1.22e7
# 30          z = 5.5; dL = 5.33e7
# 31          z = 6.6; dL = 6.59e7
# 32           z = 10; dL = 1.07e8
# 33         z = 1.75; dL = 1.34e7
# 36          z = 0.2; dL = 1.01e6
# 37       z = 2.25e-4; dL = 1.0e3
# 38          z = 1.0; dL = 6.79e6
# 39          z = 2.0; dL = 1.59e7
# 45          z = 0.1; dL = 4.76e5
# 46          z = 2.0; dL = 1.59e7
# 47          z = 8.0; dL = 8.22e7
# 48        z = 1000; dL = 1.39e10
# 49          z = 2.0; dL = 1.59e7
# 50          z = 8.0; dL = 8.22e7
# 53          z = 2.0; dL = 1.59e7
# 54          z = 8.0; dL = 8.22e7
# 56          z = 2.0; dL = 1.59e7
# 57          z = 8.0; dL = 8.22e7
# 59                       z= 1.8
# 60                        z= 3.5
# 61          z = 0.3; dL = 1.57e6
# 62          z = 5.5; dL = 5.33e7
#
#                                             Sub-specs             freq  \
# 1                         month to week before merger           0.5 Hz
# 2                                            chirping           0.5 Hz
# 3                                            chirping           0.5 Hz
# 4                                            chirping           0.5 Hz
# 6                         month to week before merger          0.29 Hz
# 8                         month to week before merger          0.11 Hz
# 10                                           chirping          0.11 Hz
# 11                                           chirping          0.11 Hz
# 12                                           chirping          0.11 Hz
# 16                        year to month before merger          3e-5 Hz
# 17                                           chirping          3e-5 Hz
# 18                                           chirping          3e-5 Hz
# 19                                           chirping          3e-5 Hz
# 21                                        post merger          2e-2 Hz
# 23                                     1 day < merger          3e-4 Hz
# 25                                     1 day < merger           0.1 Hz
# 26                        month to week before merger           0.1 Hz
# 27                        month to week before merger           0.1 Hz
# 28                        month to week before merger           0.1 Hz
# 29  low spin & eccentricity or need higher SNR; ma...           0.1 Hz
# 30  low spin & eccentricity or need higher SNR; ma...           0.1 Hz
# 31                                          SNR = 100           0.1 Hz
# 32                                          SNR = 100           0.1 Hz
# 33                                          SNR = 100           0.1 Hz
# 36  Need to pick *some* separation/orbital radius ...          5e-4 Hz
# 37  Need to pick *some* separation/orbital radius ...        5.7e-4 Hz
# 38            need something to be able to measure dL       3.68e-4 Hz
# 39            need something to be able to measure dL       2.86e-4 Hz
# 45            need something to be able to measure dL          5e-4 Hz
# 46            need something to be able to measure dL          5e-4 Hz
# 47            need something to be able to measure dL          5e-4 Hz
# 48            need something to be able to measure dL          5e-4 Hz
# 49            need something to be able to measure dL          5e-4 Hz
# 50            need something to be able to measure dL          5e-4 Hz
# 53            need something to be able to measure dL          5e-4 Hz
# 54            need something to be able to measure dL          5e-4 Hz
# 56            need something to be able to measure dL          5e-4 Hz
# 57            need something to be able to measure dL          5e-4 Hz
# 59            need something to be able to measure dL  0.01-1 Hz (ish)
# 60            need something to be able to measure dL  0.01-1 Hz (ish)
# 61                                           SNR = 50  0.01-1 Hz (ish)
# 62                                           SNR = 20  0.01-1 Hz (ish)
#
#    Required precision provisional POC label  Achievable by Concept X?  \
# 1          1 arcmin                   1.1.b                       NaN
# 2         30 arcsec                   1.1.c                       NaN
# 3            6 arcsec                 1.1.d                       NaN
# 4            1 arcsec                 1.1.e                       NaN
# 6          1 arcmin                   1.2.b                       NaN
# 8          1 arcmin                   1.3.b                       NaN
# 10        30 arcsec                   1.3.c                       NaN
# 11           6 arcsec                 1.3.d                       NaN
# 12           1 arcsec                 1.3.e                       NaN
# 16         1 arcmin                   2.1.b                       NaN
# 17        30 arcsec                   2.1.c                       NaN
# 18           6 arcsec                 2.1.d                       NaN
# 19           1 arcsec                 2.1.e                       NaN
# 21           1 arcmin                 2.2.b                       NaN
# 23         3 arcmin                   2.3.b                       NaN
# 25         3 arcmin                   3.1.a                       NaN
# 26         3 arcmin                   3.2.a                       NaN
# 27         3 arcmin                   3.2.b                       NaN
# 28         3 arcmin                   3.3.a                       NaN
# 29         3 arcmin                   3.3.b                       NaN
# 30         3 arcmin                   3.3.c                       NaN
# 31         3 arcmin                   3.3.d                       NaN
# 32         3 arcmin                   3.3.e                       NaN
# 33         3 arcmin                   3.4.a                       NaN
# 36         3 arcmin                   4.1.a                       NaN
# 37         3 arcmin                   4.1.b                       NaN
# 38         1 arcmin                   4.1.c                       NaN
# 39          20 arcsec                 4.1.d                       NaN
# 45        10 arcmin                   5.1.a                       NaN
# 46        10 arcmin                   5.1.b                       NaN
# 47        10 arcmin                   5.1.c                       NaN
# 48        10 arcmin                   5.1.d                       NaN
# 49        10 arcmin                   5.2.a                       NaN
# 50        10 arcmin                   5.2.b                       NaN
# 53        10 arcmin                   5.3.a                       NaN
# 54        10 arcmin                   5.3.b                       NaN
# 56        10 arcmin                   5.4.a                       NaN
# 57        10 arcmin                   5.4.b                       NaN
# 59        10 arcmin                   5.5.a                       NaN
# 60        10 arcmin                   5.5.b                       NaN
# 61        10 arcmin                   5.5.c                       NaN
# 62        10 arcmin                   5.6.a                       NaN
#
#                                    science motivation  \
# 1   standard sirens for cosmological structure; fo...
# 2   standard sirens for cosmological structure; fo...
# 3   standard sirens for cosmological structure; fo...
# 4   standard sirens for cosmological structure; fo...
# 6   standard sirens for cosmological structure; fo...
# 8   standard sirens for cosmological structure; fo...
# 10  standard sirens for cosmological structure; fo...
# 11  standard sirens for cosmological structure; fo...
# 12  standard sirens for cosmological structure; fo...
# 16  standard sirens for cosmological structure; fo...
# 17  standard sirens for cosmological structure; fo...
# 18  standard sirens for cosmological structure; fo...
# 19       For sub-cluster (so smaller foreground mass)
# 21       For sub-cluster (so smaller foreground mass)
# 23       For sub-cluster (so smaller foreground mass)
# 25       For sub-cluster (so smaller foreground mass)
# 26       For sub-cluster (so smaller foreground mass)
# 27       For sub-cluster (so smaller foreground mass)
# 28       For sub-cluster (so smaller foreground mass)
# 29       For sub-cluster (so smaller foreground mass)
# 30       For sub-cluster (so smaller foreground mass)
# 31       For sub-cluster (so smaller foreground mass)
# 32       For sub-cluster (so smaller foreground mass)
# 33       For sub-cluster (so smaller foreground mass)
# 36       For sub-cluster (so smaller foreground mass)
# 37       For sub-cluster (so smaller foreground mass)
# 38       For sub-cluster (so smaller foreground mass)
# 39       For sub-cluster (so smaller foreground mass)
# 45       For sub-cluster (so smaller foreground mass)
# 46       For sub-cluster (so smaller foreground mass)
# 47       For sub-cluster (so smaller foreground mass)
# 48       For sub-cluster (so smaller foreground mass)
# 49       For sub-cluster (so smaller foreground mass)
# 50       For sub-cluster (so smaller foreground mass)
# 53       For sub-cluster (so smaller foreground mass)
# 54       For sub-cluster (so smaller foreground mass)
# 56       For sub-cluster (so smaller foreground mass)
# 57       For sub-cluster (so smaller foreground mass)
# 59       For sub-cluster (so smaller foreground mass)
# 60       For sub-cluster (so smaller foreground mass)
# 61       For sub-cluster (so smaller foreground mass)
# 62       For sub-cluster (so smaller foreground mass)
#
#                             sci ref         m1           m2            z  \
# 1   Sedda et al. and Dvorkin et al.        1.5          1.5     0.050000
# 2   Sedda et al. and Dvorkin et al.        1.5          1.5     1.000000
# 3   Sedda et al. and Dvorkin et al.        1.5          1.5    20.000000
# 4   Sedda et al. and Dvorkin et al.        1.5          1.5    10.000000
# 6   Sedda et al. and Dvorkin et al.        1.5         10.0     0.200000
# 8   Sedda et al. and Dvorkin et al.       30.0         30.0     0.200000
# 10  Sedda et al. and Dvorkin et al.       30.0         30.0     1.000000
# 11  Sedda et al. and Dvorkin et al.       30.0         30.0    20.000000
# 12  Sedda et al. and Dvorkin et al.       30.0         30.0    10.000000
# 16  Sedda et al. and Dvorkin et al.  1000000.0    1000000.0     1.000000
# 17  Sedda et al. and Dvorkin et al.  1000000.0    1000000.0     1.000000
# 18  Sedda et al. and Dvorkin et al.  1000000.0    1000000.0    20.000000
# 19  Sedda et al. and Dvorkin et al.  1000000.0    1000000.0    10.000000
# 21  Sedda et al. and Dvorkin et al.   500000.0     500000.0     2.000000
# 23  Sedda et al. and Dvorkin et al.   500000.0     500000.0     2.000000
# 25  Sedda et al. and Dvorkin et al.      100.0  100000000.0     0.500000
# 26  Sedda et al. and Dvorkin et al.        1.0   10000000.0     0.200000
# 27  Sedda et al. and Dvorkin et al.        1.0   10000000.0     0.200000
# 28  Sedda et al. and Dvorkin et al.       10.0     500000.0     1.500000
# 29  Sedda et al. and Dvorkin et al.       10.0     500000.0     1.500000
# 30  Sedda et al. and Dvorkin et al.       10.0     500000.0     5.500000
# 31  Sedda et al. and Dvorkin et al.       10.0     500000.0     6.600000
# 32  Sedda et al. and Dvorkin et al.       10.0     500000.0    10.000000
# 33  Sedda et al. and Dvorkin et al.   500000.0          0.6     1.750000
# 36  Sedda et al. and Dvorkin et al.        0.6          0.6     0.200000
# 37  Sedda et al. and Dvorkin et al.        0.6          0.6     0.000225
# 38  Sedda et al. and Dvorkin et al.        0.6          0.6     1.000000
# 39  Sedda et al. and Dvorkin et al.        0.6          0.6     2.000000
# 45  Sedda et al. and Dvorkin et al.      100.0         10.0     0.100000
# 46  Sedda et al. and Dvorkin et al.      100.0         10.0     2.000000
# 47  Sedda et al. and Dvorkin et al.      100.0         10.0     8.000000
# 48  Sedda et al. and Dvorkin et al.      100.0         10.0  1000.000000
# 49  Sedda et al. and Dvorkin et al.     2000.0         40.0     2.000000
# 50  Sedda et al. and Dvorkin et al.     2000.0         40.0     8.000000
# 53  Sedda et al. and Dvorkin et al.     1000.0        100.0     2.000000
# 54  Sedda et al. and Dvorkin et al.     1000.0        100.0     8.000000
# 56  Sedda et al. and Dvorkin et al.     1000.0       1000.0     2.000000
# 57  Sedda et al. and Dvorkin et al.     1000.0       1000.0     8.000000
# 59  Sedda et al. and Dvorkin et al.        3.0          0.8     1.800000
# 60  Sedda et al. and Dvorkin et al.        3.0          0.8     3.500000
# 61  Sedda et al. and Dvorkin et al.     5000.0          1.0     0.300000
# 62  Sedda et al. and Dvorkin et al.  1000000.0       1000.0     5.500000
#
#             dist  timecut    SNR     CW        f0  resolution
# 1   2.245822e+05     15.0    NaN  False       NaN        60.0
# 2   6.726141e+06      NaN    NaN  False       NaN        30.0
# 3   2.316106e+08      NaN    NaN  False       NaN         6.0
# 4   1.065544e+08      NaN    NaN  False       NaN         1.0
# 6   9.916448e+05     15.0    NaN  False       NaN        60.0
# 8   9.916448e+05     15.0    NaN  False       NaN        60.0
# 10  6.726141e+06      NaN    NaN  False       NaN        30.0
# 11  2.316106e+08      NaN    NaN  False       NaN         6.0
# 12  1.065544e+08      NaN    NaN  False       NaN         1.0
# 16  6.726141e+06    180.0    NaN  False       NaN        60.0
# 17  6.726141e+06      NaN    NaN  False       NaN        30.0
# 18  2.316106e+08      NaN    NaN  False       NaN         6.0
# 19  1.065544e+08      NaN    NaN  False       NaN         1.0
# 21  1.587519e+07      NaN    NaN  False       NaN        60.0
# 23  1.587519e+07      NaN    NaN  False       NaN       180.0
# 25  2.874104e+06      NaN    NaN  False       NaN       180.0
# 26  9.916448e+05     15.0    NaN  False       NaN       180.0
# 27  9.916448e+05     15.0    NaN  False       NaN       180.0
# 28  1.112937e+07     15.0    NaN  False       NaN       180.0
# 29  1.112937e+07      NaN    NaN  False       NaN       180.0
# 30  5.346936e+07      NaN    NaN  False       NaN       180.0
# 31  6.612339e+07      NaN  100.0  False       NaN       180.0
# 32  1.065544e+08      NaN  100.0  False       NaN       180.0
# 33  1.346761e+07      NaN  100.0  False       NaN       180.0
# 36  9.916448e+05      NaN    NaN   True  0.000500       180.0
# 37  9.732432e+02      NaN    NaN   True  0.000570       180.0
# 38  6.726141e+06      NaN    NaN   True  0.000368        60.0
# 39  1.587519e+07      NaN    NaN   True  0.000286        20.0
# 45  4.652806e+05      NaN    NaN  False       NaN       600.0
# 46  1.587519e+07      NaN    NaN  False       NaN       600.0
# 47  8.256570e+07      NaN    NaN  False       NaN       600.0
# 48  1.399733e+10      NaN    NaN  False       NaN       600.0
# 49  1.587519e+07      NaN    NaN  False       NaN       600.0
# 50  8.256570e+07      NaN    NaN  False       NaN       600.0
# 53  1.587519e+07      NaN    NaN  False       NaN       600.0
# 54  8.256570e+07      NaN    NaN  False       NaN       600.0
# 56  1.587519e+07      NaN    NaN  False       NaN       600.0
# 57  8.256570e+07      NaN    NaN  False       NaN       600.0
# 59  1.394397e+07      NaN    NaN  False       NaN       600.0
# 60  3.131238e+07      NaN    NaN  False       NaN       600.0
# 61  1.572542e+06      NaN   50.0  False       NaN       600.0
# 62  5.346936e+07      NaN   20.0  False       NaN       600.0

# %%
# make source dictionaries
objectiveList=[]
minimumSNR=5
for i,row in df.iterrows():
    obj={}
    obj['label']=row['provisional POC label']
    obj['m1']=row['m1']*(1+row['z'])#convert to redshifted mass
    obj['m2']=row['m2']*(1+row['z'])#convert to redshifted mass
    dist=cosmo.luminosity_distance(row['z']).to(u.kpc).value
    obj['dl']=dist
    if row['CW']:
        obj['type']='CW'
        obj['f0']=row['f0']
    else:
        obj['type']='chirp'
        if np.isfinite(row['timecut']):
            obj['timecut']=row['timecut']
    #Now add the conditions
    conditions={}
    if np.isfinite(row['resolution']):
        conditions['resolution']=row['resolution']/3600/180*np.pi #convert arcsec to rad
    snr=minimumSNR
    if np.isfinite(row['SNR']): snr=max([minimumSNR,row['SNR']])
    conditions['SNR']=snr
    obj['conditions']=conditions
    objectiveList.append(obj)

# %% [markdown]
# ### Perform the observations and assessment
# We first compute the SNR and then the angular resolution

# %%
for mission in missions:
    print('\nProcessing mission',mission['label'],'\n')
    obs = list()
    for s in objectiveList:
        print('\nProcessing:',s.get('label','--unnamed--'))
        print(s)
        sgn=-1; 
        #if s['type']=='CW': sgn=1 #There is currently a pathology with getSourceSnr, it needs T>0 for CW and T<0 for chirp
        ob = metrics.getSourceSnr(s,mission,sgn*4.0*constants.year)
        ob = metrics.getResolution(ob)
        print('SNR,res',ob['SNR'],ob['Angular Resolution'])
        #Perform the assessment
        #The assessment is based on the ratio of the estimated capability to the objective for each of
        #resolution and SNR, with <=1 meaning that the objective is met
        #A total is based on the worst of those present
        conditions=s['conditions']
        assessment={}
        alleps=[]
        print(conditions)
        if 'SNR' in conditions:
            #eps=ob['SNR']/conditions['SNR']
            eps=conditions['SNR']/ob['SNR']
            assessment['eps_SNR']=eps
            alleps.append(eps)
        if 'resolution' in conditions:
            #eps=conditions['resolution']/ob['Angular Resolution']
            eps=ob['Angular Resolution']/conditions['resolution']
            #print(ob['Angular Resolution'][-1],conditions['resolution'],eps)
            assessment['eps_res']=eps
            alleps.append(eps)
        #print('alleps',alleps)
        if len(alleps)>0: 
            assessment['eps']=max(alleps)*(1+sum(alleps)*0) #The last factor ensures that NANs stay NANs
        ob['assessment']=assessment    
        print(assessment)
        obs.append(ob)
        
    mission['obs']=obs
# Out:
# Processing mission LISA(CBE)
#
#
# Processing: 1.1.b
# {'label': '1.1.b', 'm1': 1.5750000000000002, 'm2': 1.5750000000000002, 'dl': 224582.2244309782, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot = 1.5e-05, eta = 0.25, ds = 2.3e+16, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.05468339309242509 nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 91.43543802318688, 'eps_res': nan, 'eps': nan}
#
# Processing: 1.1.c
# {'label': '1.1.c', 'm1': 3.0, 'm2': 3.0, 'dl': 6726141.242139786, 'type': 'chirp', 'conditions': {'resolution': 0.0001454441043328608, 'SNR': 5}}
# mtot = 2.8e-05, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.006014690655867852 1.9237643675446499
# {'resolution': 0.0001454441043328608, 'SNR': 5}
# {'eps_SNR': 831.2979479870784, 'eps_res': 13226.829484555503, 'eps': 13226.829484555503}
#
# Processing: 1.1.d
# {'label': '1.1.d', 'm1': 31.5, 'm2': 31.5, 'dl': 231610636.3389375, 'type': 'chirp', 'conditions': {'resolution': 2.9088820866572157e-05, 'SNR': 5}}
# mtot = 0.0003, eta = 0.25, ds = 2.4e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.010332264309664234 4.667101438395787
# {'resolution': 2.9088820866572157e-05, 'SNR': 5}
# {'eps_SNR': 483.92103126158645, 'eps_res': 160443.12898770862, 'eps': 160443.12898770862}
#
# Processing: 1.1.e
# {'label': '1.1.e', 'm1': 16.5, 'm2': 16.5, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 4.84813681109536e-06, 'SNR': 5}}
# mtot = 0.00016, eta = 0.25, ds = 1.1e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.00783604039649788 4.179073093394381
# {'resolution': 4.84813681109536e-06, 'SNR': 5}
# {'eps_SNR': 638.0773639496069, 'eps_res': 861995.7019014456, 'eps': 861995.7019014456}
#
# Processing: 1.2.b
# {'label': '1.2.b', 'm1': 1.7999999999999998, 'm2': 12.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot = 6.5e-05, eta = 0.11, ds = 1e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.0787240176475461 nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 63.513018636642904, 'eps_res': nan, 'eps': nan}
#
# Processing: 1.3.b
# {'label': '1.3.b', 'm1': 36.0, 'm2': 36.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot = 0.00034, eta = 0.25, ds = 1e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 2.9741007486332856 nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 1.6811804382543845, 'eps_res': nan, 'eps': nan}
#
# Processing: 1.3.c
# {'label': '1.3.c', 'm1': 60.0, 'm2': 60.0, 'dl': 6726141.242139786, 'type': 'chirp', 'conditions': {'resolution': 0.0001454441043328608, 'SNR': 5}}
# mtot = 0.00057, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.9501163208086445 0.07397697126638549
# {'resolution': 0.0001454441043328608, 'SNR': 5}
# {'eps_SNR': 5.262513537020917, 'eps_res': 508.6281881669339, 'eps': 508.6281881669339}
#
# Processing: 1.3.d
# {'label': '1.3.d', 'm1': 630.0, 'm2': 630.0, 'dl': 231610636.3389375, 'type': 'chirp', 'conditions': {'resolution': 2.9088820866572157e-05, 'SNR': 5}}
# mtot = 0.006, eta = 0.25, ds = 2.4e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.5438325302315608 0.40004324992920987
# {'resolution': 2.9088820866572157e-05, 'SNR': 5}
# {'eps_SNR': 9.194006834918516, 'eps_res': 13752.473906184538, 'eps': 13752.473906184538}
#
# Processing: 1.3.e
# {'label': '1.3.e', 'm1': 330.0, 'm2': 330.0, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 4.84813681109536e-06, 'SNR': 5}}
# mtot = 0.0031, eta = 0.25, ds = 1.1e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.5901734685108496 0.3019632176412051
# {'resolution': 4.84813681109536e-06, 'SNR': 5}
# {'eps_SNR': 8.47208535588055, 'eps_res': 62284.38458051296, 'eps': 62284.38458051296}
#
# Processing: 2.1.b
# {'label': '2.1.b', 'm1': 2000000.0, 'm2': 2000000.0, 'dl': 6726141.242139786, 'type': 'chirp', 'timecut': 180.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot =  19, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 14605.228028413501 nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 0.00034234316576727404, 'eps_res': nan, 'eps': nan}
#
# Processing: 2.1.c
# {'label': '2.1.c', 'm1': 2000000.0, 'm2': 2000000.0, 'dl': 6726141.242139786, 'type': 'chirp', 'conditions': {'resolution': 0.0001454441043328608, 'SNR': 5}}
# mtot =  19, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 14605.228028413501 0.0012351599068684037
# {'resolution': 0.0001454441043328608, 'SNR': 5}
# {'eps_SNR': 0.00034234316576727404, 'eps_res': 8.492333962479762, 'eps': 8.492333962479762}
#
# Processing: 2.1.d
# {'label': '2.1.d', 'm1': 21000000.0, 'm2': 21000000.0, 'dl': 231610636.3389375, 'type': 'chirp', 'conditions': {'resolution': 2.9088820866572157e-05, 'SNR': 5}}
# mtot = 2e+02, eta = 0.25, ds = 2.4e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 121.69484345932713 0.7975846758528986
# {'resolution': 2.9088820866572157e-05, 'SNR': 5}
# {'eps_SNR': 0.04108637521417332, 'eps_res': 27418.94143840855, 'eps': 27418.94143840855}
#
# Processing: 2.1.e
# {'label': '2.1.e', 'm1': 11000000.0, 'm2': 11000000.0, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 4.84813681109536e-06, 'SNR': 5}}
# mtot = 1e+02, eta = 0.25, ds = 1.1e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 468.31108864763996 0.14602976572618823
# {'resolution': 4.84813681109536e-06, 'SNR': 5}
# {'eps_SNR': 0.01067666369899268, 'eps_res': 30120.801333821088, 'eps': 30120.801333821088}
#
# Processing: 2.2.b
# {'label': '2.2.b', 'm1': 1500000.0, 'm2': 1500000.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot =  14, eta = 0.25, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 5449.212956076004 0.002546825238475278
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 0.0009175636996210396, 'eps_res': 8.75534023932197, 'eps': 8.75534023932197}
#
# Processing: 2.3.b
# {'label': '2.3.b', 'm1': 1500000.0, 'm2': 1500000.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  14, eta = 0.25, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 5449.212956076004 0.002546825238475278
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.0009175636996210396, 'eps_res': 2.9184467464406567, 'eps': 2.9184467464406567}
#
# Processing: 3.1.a
# {'label': '3.1.a', 'm1': 150.0, 'm2': 150000000.0, 'dl': 2874104.125862455, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot = 7.1e+02, eta = 1e-06, ds = 3e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.2.a
# {'label': '3.2.a', 'm1': 1.2, 'm2': 12000000.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  57, eta = 1e-07, ds = 1e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.2.b
# {'label': '3.2.b', 'm1': 1.2, 'm2': 12000000.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  57, eta = 1e-07, ds = 1e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.3.a
# {'label': '3.3.a', 'm1': 25.0, 'm2': 1250000.0, 'dl': 11129368.800256329, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot = 5.9, eta = 2e-05, ds = 1.1e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 34.756170152083484 nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.1438593486601478, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.3.b
# {'label': '3.3.b', 'm1': 25.0, 'm2': 1250000.0, 'dl': 11129368.800256329, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot = 5.9, eta = 2e-05, ds = 1.1e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 34.756170152083484 0.0019528861550377572
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.1438593486601478, 'eps_res': 2.2378426910638884, 'eps': 2.2378426910638884}
#
# Processing: 3.3.c
# {'label': '3.3.c', 'm1': 65.0, 'm2': 3250000.0, 'dl': 53469364.83606955, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  15, eta = 2e-05, ds = 5.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 12.279878549337656 0.14991622738883698
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.40717015073977963, 'eps_res': 171.79134219807833, 'eps': 171.79134219807833}
#
# Processing: 3.3.d
# {'label': '3.3.d', 'm1': 76.0, 'm2': 3800000.0, 'dl': 66123392.56646311, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 100.0}}
# mtot =  18, eta = 2e-05, ds = 6.8e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 9.944459338013061 0.2093742236462765
# {'resolution': 0.0008726646259971648, 'SNR': 100.0}
# {'eps_SNR': 10.055850861368231, 'eps_res': 239.9251870751969, 'eps': 239.9251870751969}
#
# Processing: 3.3.e
# {'label': '3.3.e', 'm1': 110.0, 'm2': 5500000.0, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 100.0}}
# mtot =  26, eta = 2e-05, ds = 1.1e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 5.593633626752201 0.5037472403697877
# {'resolution': 0.0008726646259971648, 'SNR': 100.0}
# {'eps_SNR': 17.87746689767782, 'eps_res': 577.2518162910208, 'eps': 577.2518162910208}
#
# Processing: 3.4.a
# {'label': '3.4.a', 'm1': 1375000.0, 'm2': 1.65, 'dl': 13467605.79493649, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 100.0}}
# mtot = 6.5, eta = 1.2e-06, ds = 1.4e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 7.530591539887425 0.02106430453764081
# {'resolution': 0.0008726646259971648, 'SNR': 100.0}
# {'eps_SNR': 13.279169301684753, 'eps_res': 24.137914967701747, 'eps': 24.137914967701747}
#
# Processing: 4.1.a
# {'label': '4.1.a', 'm1': 0.72, 'm2': 0.72, 'dl': 991644.8422591747, 'type': 'CW', 'f0': 0.0005, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# snrt: len,min,max= 1000 4.4957239065129904e-10 4.4957239065129904e-10
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 4.1.b
# {'label': '4.1.b', 'm1': 0.600135, 'm2': 0.600135, 'dl': 973.2431716602136, 'type': 'CW', 'f0': 0.00057, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# snrt: len,min,max= 1000 5.675842902039941e-07 5.675842902039941e-07
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 4.1.c
# {'label': '4.1.c', 'm1': 1.2, 'm2': 1.2, 'dl': 6726141.242139786, 'type': 'CW', 'f0': 0.000368, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# snrt: len,min,max= 1000 4.229897112664705e-11 4.229897112664705e-11
# SNR,res nan nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 4.1.d
# {'label': '4.1.d', 'm1': 1.7999999999999998, 'm2': 1.7999999999999998, 'dl': 15875191.123148063, 'type': 'CW', 'f0': 0.000286, 'conditions': {'resolution': 9.69627362219072e-05, 'SNR': 5}}
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# snrt: len,min,max= 1000 1.1790782093442036e-11 1.1790782093442036e-11
# SNR,res nan nan
# {'resolution': 9.69627362219072e-05, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 5.1.a
# {'label': '5.1.a', 'm1': 110.00000000000001, 'm2': 11.0, 'dl': 465280.59136148746, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.00057, eta = 0.083, ds = 4.8e+16, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 5.053620226268321 0.009415706580263623
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.9893897396583924, 'eps_res': 3.236881489095978, 'eps': 3.236881489095978}
#
# Processing: 5.1.b
# {'label': '5.1.b', 'm1': 300.0, 'm2': 30.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.0016, eta = 0.083, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.666393072543611 0.1275937616619687
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 7.50307919755991, 'eps_res': 43.863504212573616, 'eps': 43.863504212573616}
#
# Processing: 5.1.c
# {'label': '5.1.c', 'm1': 900.0, 'm2': 90.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.0047, eta = 0.083, ds = 8.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.5583185306282206 0.27858936188260813
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 8.955461310542558, 'eps_res': 95.77196791869731, 'eps': 95.77196791869731}
#
# Processing: 5.1.d
# {'label': '5.1.d', 'm1': 100100.0, 'm2': 10010.0, 'dl': 13997333920.647652, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.52, eta = 0.083, ds = 1.4e+21, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.23594932484118994 15.3002892658317
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 21.190990918771828, 'eps_res': 5259.85200156884, 'eps': 5259.85200156884}
#
# Processing: 5.2.a
# {'label': '5.2.a', 'm1': 6000.0, 'm2': 120.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.029, eta = 0.019, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 8.26660442603266 0.02510077753190758
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.6048432636082501, 'eps_res': 8.629011690450646, 'eps': 8.629011690450646}
#
# Processing: 5.2.b
# {'label': '5.2.b', 'm1': 18000.0, 'm2': 360.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.087, eta = 0.019, ds = 8.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 4.281645555036667 0.048422452137739706
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 1.1677753180943022, 'eps_res': 16.6464128470003, 'eps': 16.6464128470003}
#
# Processing: 5.3.a
# {'label': '5.3.a', 'm1': 3000.0, 'm2': 300.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.016, eta = 0.083, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 10.566340256935447 0.020732460474509593
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.4732007372863221, 'eps_res': 7.127294904667175, 'eps': 7.127294904667175}
#
# Processing: 5.3.b
# {'label': '5.3.b', 'm1': 9000.0, 'm2': 900.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.047, eta = 0.083, ds = 8.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 5.330552883158021 0.05241876232381008
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.9379890059430028, 'eps_res': 18.020243090722136, 'eps': 18.020243090722136}
#
# Processing: 5.4.a
# {'label': '5.4.a', 'm1': 3000.0, 'm2': 3000.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.028, eta = 0.25, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 31.826606374654176 0.011239031236317091
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.15710126116310852, 'eps_res': 3.863694333940015, 'eps': 3.863694333940015}
#
# Processing: 5.4.b
# {'label': '5.4.b', 'm1': 9000.0, 'm2': 9000.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.085, eta = 0.25, ds = 8.5e+18, T = -1.3e+08
# /Users/jgbaker/Projects/FGRST/GWImager/GWI-metrics/Notebooks/../src/metrics.py:169: RuntimeWarning: invalid value encountered in log10
#   tvals = -np.flip(np.logspace(np.log10(-tstop),np.log10(-tstart),Npts))
# /Users/jgbaker/Projects/FGRST/GWImager/GWI-metrics/Notebooks/../src/PhenomWaveform_nonspinning.py:158: RuntimeWarning: invalid value encountered in power
#   omegavals = (xvals**1.5)/M
# /Users/jgbaker/Projects/FGRST/GWImager/GWI-metrics/Notebooks/../src/metrics.py:178: RuntimeWarning: invalid value encountered in sqrt
#   snrt = np.sqrt(np.cumsum(np.diff(fvals)*snri[1:]))
# /Users/jgbaker/Projects/FGRST/GWImager/GWI-metrics/Notebooks/../src/metrics.py:158: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(rho2)
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 15.365369239430207 0.09249973559606531
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.32540708407899055, 'eps_res': 31.799066734383427, 'eps': 31.799066734383427}
#
# Processing: 5.5.a
# {'label': '5.5.a', 'm1': 8.399999999999999, 'm2': 2.2399999999999998, 'dl': 13943971.392771732, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 5e-05, eta = 0.17, ds = 1.4e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.005291910769106654 2.6676765219064857
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 944.8383047554802, 'eps_res': 917.0796348682821, 'eps': 944.8383047554802}
#
# Processing: 5.5.b
# {'label': '5.5.b', 'm1': 13.5, 'm2': 3.6, 'dl': 31312381.449641217, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 8.1e-05, eta = 0.17, ds = 3.2e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.005554817434776225 3.3898369771285277
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 900.1195914553805, 'eps_res': 1165.3401121610977, 'eps': 1165.3401121610977}
#
# Processing: 5.5.c
# {'label': '5.5.c', 'm1': 6500.0, 'm2': 1.3, 'dl': 1572542.1375814416, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 50.0}}
# mtot = 0.031, eta = 0.0002, ds = 1.6e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 2.650530423452507 0.021019888761382662
# {'resolution': 0.0029088820866572155, 'SNR': 50.0}
# {'eps_SNR': 18.86414868419861, 'eps_res': 7.2261054711701895, 'eps': 18.86414868419861}
#
# Processing: 5.6.a
# {'label': '5.6.a', 'm1': 6500000.0, 'm2': 6500.0, 'dl': 53469364.83606955, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 20.0}}
# mtot =  31, eta = 0.001, ds = 5.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 73.04936746337647 0.006862689129825038
# {'resolution': 0.0029088820866572155, 'SNR': 20.0}
# {'eps_SNR': 0.27378744942626726, 'eps_res': 2.3592187394956934, 'eps': 2.3592187394956934}
#
# Processing mission LISA(SciRDv1)
#
#
# Processing: 1.1.b
# {'label': '1.1.b', 'm1': 1.5750000000000002, 'm2': 1.5750000000000002, 'dl': 224582.2244309782, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot = 1.5e-05, eta = 0.25, ds = 2.3e+16, T = -1.3e+08
# SNR,res 0.03782337624171533 nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 132.19338136412873, 'eps_res': nan, 'eps': nan}
#
# Processing: 1.1.c
# {'label': '1.1.c', 'm1': 3.0, 'm2': 3.0, 'dl': 6726141.242139786, 'type': 'chirp', 'conditions': {'resolution': 0.0001454441043328608, 'SNR': 5}}
# mtot = 2.8e-05, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# SNR,res 0.0041602384857887375 2.781294294807386
# {'resolution': 0.0001454441043328608, 'SNR': 5}
# {'eps_SNR': 1201.8541766487342, 'eps_res': 19122.770961153332, 'eps': 19122.770961153332}
#
# Processing: 1.1.d
# {'label': '1.1.d', 'm1': 31.5, 'm2': 31.5, 'dl': 231610636.3389375, 'type': 'chirp', 'conditions': {'resolution': 2.9088820866572157e-05, 'SNR': 5}}
# mtot = 0.0003, eta = 0.25, ds = 2.4e+19, T = -1.3e+08
# SNR,res 0.007147296774749998 6.746848093936344
# {'resolution': 2.9088820866572157e-05, 'SNR': 5}
# {'eps_SNR': 699.565186332268, 'eps_res': 231939.5524790619, 'eps': 231939.5524790619}
#
# Processing: 1.1.e
# {'label': '1.1.e', 'm1': 16.5, 'm2': 16.5, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 4.84813681109536e-06, 'SNR': 5}}
# mtot = 0.00016, eta = 0.25, ds = 1.1e+19, T = -1.3e+08
# SNR,res 0.00542011870146379 6.041820739260151
# {'resolution': 4.84813681109536e-06, 'SNR': 5}
# {'eps_SNR': 922.4890219931291, 'eps_res': 1246214.9841631835, 'eps': 1246214.9841631835}
#
# Processing: 1.2.b
# {'label': '1.2.b', 'm1': 1.7999999999999998, 'm2': 12.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot = 6.5e-05, eta = 0.11, ds = 1e+17, T = -1.3e+08
# SNR,res 0.054451837419390005 nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 91.82426593780153, 'eps_res': nan, 'eps': nan}
#
# Processing: 1.3.b
# {'label': '1.3.b', 'm1': 36.0, 'm2': 36.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot = 0.00034, eta = 0.25, ds = 1e+17, T = -1.3e+08
# SNR,res 2.057412871962422 nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 2.4302365694984935, 'eps_res': nan, 'eps': nan}
#
# Processing: 1.3.c
# {'label': '1.3.c', 'm1': 60.0, 'm2': 60.0, 'dl': 6726141.242139786, 'type': 'chirp', 'conditions': {'resolution': 0.0001454441043328608, 'SNR': 5}}
# mtot = 0.00057, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# SNR,res 0.6575594767333692 0.10689029700150642
# {'resolution': 0.0001454441043328608, 'SNR': 5}
# {'eps_SNR': 7.603874899406898, 'eps_res': 734.9235466903435, 'eps': 734.9235466903435}
#
# Processing: 1.3.d
# {'label': '1.3.d', 'm1': 630.0, 'm2': 630.0, 'dl': 231610636.3389375, 'type': 'chirp', 'conditions': {'resolution': 2.9088820866572157e-05, 'SNR': 5}}
# mtot = 0.006, eta = 0.25, ds = 2.4e+19, T = -1.3e+08
# SNR,res 0.4026331334648937 0.5851434581866621
# {'resolution': 2.9088820866572157e-05, 'SNR': 5}
# {'eps_SNR': 12.418252708047333, 'eps_res': 20115.7503382713, 'eps': 20115.7503382713}
#
# Processing: 1.3.e
# {'label': '1.3.e', 'm1': 330.0, 'm2': 330.0, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 4.84813681109536e-06, 'SNR': 5}}
# mtot = 0.0031, eta = 0.25, ds = 1.1e+19, T = -1.3e+08
# SNR,res 0.4209258491015718 0.435088799737142
# {'resolution': 4.84813681109536e-06, 'SNR': 5}
# {'eps_SNR': 11.878576739043345, 'eps_res': 89743.5069780633, 'eps': 89743.5069780633}
#
# Processing: 2.1.b
# {'label': '2.1.b', 'm1': 2000000.0, 'm2': 2000000.0, 'dl': 6726141.242139786, 'type': 'chirp', 'timecut': 180.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot =  19, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# SNR,res 11947.305085446651 nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 0.00041850442122639365, 'eps_res': nan, 'eps': nan}
#
# Processing: 2.1.c
# {'label': '2.1.c', 'm1': 2000000.0, 'm2': 2000000.0, 'dl': 6726141.242139786, 'type': 'chirp', 'conditions': {'resolution': 0.0001454441043328608, 'SNR': 5}}
# mtot =  19, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# SNR,res 11947.305085446651 0.0015099465496484054
# {'resolution': 0.0001454441043328608, 'SNR': 5}
# {'eps_SNR': 0.00041850442122639365, 'eps_res': 10.381627750223334, 'eps': 10.381627750223334}
#
# Processing: 2.1.d
# {'label': '2.1.d', 'm1': 21000000.0, 'm2': 21000000.0, 'dl': 231610636.3389375, 'type': 'chirp', 'conditions': {'resolution': 2.9088820866572157e-05, 'SNR': 5}}
# mtot = 2e+02, eta = 0.25, ds = 2.4e+19, T = -1.3e+08
# SNR,res 117.44020840583276 0.8264796494405404
# {'resolution': 2.9088820866572157e-05, 'SNR': 5}
# {'eps_SNR': 0.042574856327925854, 'eps_res': 28412.277459836867, 'eps': 28412.277459836867}
#
# Processing: 2.1.e
# {'label': '2.1.e', 'm1': 11000000.0, 'm2': 11000000.0, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 4.84813681109536e-06, 'SNR': 5}}
# mtot = 1e+02, eta = 0.25, ds = 1.1e+19, T = -1.3e+08
# SNR,res 443.12481174372135 0.15432978869561123
# {'resolution': 4.84813681109536e-06, 'SNR': 5}
# {'eps_SNR': 0.011283502678003326, 'eps_res': 31832.80396345557, 'eps': 31832.80396345557}
#
# Processing: 2.2.b
# {'label': '2.2.b', 'm1': 1500000.0, 'm2': 1500000.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot =  14, eta = 0.25, ds = 1.6e+18, T = -1.3e+08
# SNR,res 4296.753026794508 0.003229925713629938
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 0.001163669396127739, 'eps_res': 11.103666691906561, 'eps': 11.103666691906561}
#
# Processing: 2.3.b
# {'label': '2.3.b', 'm1': 1500000.0, 'm2': 1500000.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  14, eta = 0.25, ds = 1.6e+18, T = -1.3e+08
# SNR,res 4296.753026794508 0.003229925713629938
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.001163669396127739, 'eps_res': 3.70122223063552, 'eps': 3.70122223063552}
#
# Processing: 3.1.a
# {'label': '3.1.a', 'm1': 150.0, 'm2': 150000000.0, 'dl': 2874104.125862455, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot = 7.1e+02, eta = 1e-06, ds = 3e+17, T = -1.3e+08
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.2.a
# {'label': '3.2.a', 'm1': 1.2, 'm2': 12000000.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  57, eta = 1e-07, ds = 1e+17, T = -1.3e+08
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.2.b
# {'label': '3.2.b', 'm1': 1.2, 'm2': 12000000.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  57, eta = 1e-07, ds = 1e+17, T = -1.3e+08
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.3.a
# {'label': '3.3.a', 'm1': 25.0, 'm2': 1250000.0, 'dl': 11129368.800256329, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot = 5.9, eta = 2e-05, ds = 1.1e+18, T = -1.3e+08
# SNR,res 26.723932947321828 nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.1870982093038473, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.3.b
# {'label': '3.3.b', 'm1': 25.0, 'm2': 1250000.0, 'dl': 11129368.800256329, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot = 5.9, eta = 2e-05, ds = 1.1e+18, T = -1.3e+08
# SNR,res 26.723932947321828 0.0025398523348316715
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.1870982093038473, 'eps_res': 2.9104563874460556, 'eps': 2.9104563874460556}
#
# Processing: 3.3.c
# {'label': '3.3.c', 'm1': 65.0, 'm2': 3250000.0, 'dl': 53469364.83606955, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  15, eta = 2e-05, ds = 5.5e+18, T = -1.3e+08
# SNR,res 10.294386390491225 0.17883077194482103
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.485701605742954, 'eps_res': 204.92496959009546, 'eps': 204.92496959009546}
#
# Processing: 3.3.d
# {'label': '3.3.d', 'm1': 76.0, 'm2': 3800000.0, 'dl': 66123392.56646311, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 100.0}}
# mtot =  18, eta = 2e-05, ds = 6.8e+18, T = -1.3e+08
# SNR,res 8.573771792588541 0.24284684778737625
# {'resolution': 0.0008726646259971648, 'SNR': 100.0}
# {'eps_SNR': 11.663478153972257, 'eps_res': 278.28198892545146, 'eps': 278.28198892545146}
#
# Processing: 3.3.e
# {'label': '3.3.e', 'm1': 110.0, 'm2': 5500000.0, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 100.0}}
# mtot =  26, eta = 2e-05, ds = 1.1e+19, T = -1.3e+08
# SNR,res 5.080355037317192 0.5546418473548387
# {'resolution': 0.0008726646259971648, 'SNR': 100.0}
# {'eps_SNR': 19.683663693868034, 'eps_res': 635.57273989543, 'eps': 635.57273989543}
#
# Processing: 3.4.a
# {'label': '3.4.a', 'm1': 1375000.0, 'm2': 1.65, 'dl': 13467605.79493649, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 100.0}}
# mtot = 6.5, eta = 1.2e-06, ds = 1.4e+18, T = -1.3e+08
# SNR,res 5.782739250676597 0.02743106107130983
# {'resolution': 0.0008726646259971648, 'SNR': 100.0}
# {'eps_SNR': 17.292842659004503, 'eps_res': 31.433680539033272, 'eps': 31.433680539033272}
#
# Processing: 4.1.a
# {'label': '4.1.a', 'm1': 0.72, 'm2': 0.72, 'dl': 991644.8422591747, 'type': 'CW', 'f0': 0.0005, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# snrt: len,min,max= 1000 4.2958040171469894e-10 4.2958040171469894e-10
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 4.1.b
# {'label': '4.1.b', 'm1': 0.600135, 'm2': 0.600135, 'dl': 973.2431716602136, 'type': 'CW', 'f0': 0.00057, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# snrt: len,min,max= 1000 5.399936140384995e-07 5.399936140384995e-07
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 4.1.c
# {'label': '4.1.c', 'm1': 1.2, 'm2': 1.2, 'dl': 6726141.242139786, 'type': 'CW', 'f0': 0.000368, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# snrt: len,min,max= 1000 4.086336850360257e-11 4.086336850360257e-11
# SNR,res nan nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 4.1.d
# {'label': '4.1.d', 'm1': 1.7999999999999998, 'm2': 1.7999999999999998, 'dl': 15875191.123148063, 'type': 'CW', 'f0': 0.000286, 'conditions': {'resolution': 9.69627362219072e-05, 'SNR': 5}}
# snrt: len,min,max= 1000 1.1491640227528058e-11 1.1491640227528058e-11
# SNR,res nan nan
# {'resolution': 9.69627362219072e-05, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 5.1.a
# {'label': '5.1.a', 'm1': 110.00000000000001, 'm2': 11.0, 'dl': 465280.59136148746, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.00057, eta = 0.083, ds = 4.8e+16, T = -1.3e+08
# SNR,res 3.495808277708771 0.01361156031411859
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 1.430284387128092, 'eps_res': 4.679309751520562, 'eps': 4.679309751520562}
#
# Processing: 5.1.b
# {'label': '5.1.b', 'm1': 300.0, 'm2': 30.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.0016, eta = 0.083, ds = 1.6e+18, T = -1.3e+08
# SNR,res 0.4616034372276931 0.18420053234866907
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 10.831808424194364, 'eps_res': 63.32347852585039, 'eps': 63.32347852585039}
#
# Processing: 5.1.c
# {'label': '5.1.c', 'm1': 900.0, 'm2': 90.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.0047, eta = 0.083, ds = 8.5e+18, T = -1.3e+08
# SNR,res 0.3936115062497799 0.4017909162276128
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 12.702880684659345, 'eps_res': 138.12554247921983, 'eps': 138.12554247921983}
#
# Processing: 5.1.d
# {'label': '5.1.d', 'm1': 100100.0, 'm2': 10010.0, 'dl': 13997333920.647652, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.52, eta = 0.083, ds = 1.4e+21, T = -1.3e+08
# SNR,res 0.18178027738959968 19.189053314460487
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 27.505734240265102, 'eps_res': 6596.710606620659, 'eps': 6596.710606620659}
#
# Processing: 5.2.a
# {'label': '5.2.a', 'm1': 6000.0, 'm2': 120.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.029, eta = 0.019, ds = 1.6e+18, T = -1.3e+08
# SNR,res 6.133687616406928 0.03732983480120762
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.8151703041781194, 'eps_res': 12.833051904178676, 'eps': 12.833051904178676}
#
# Processing: 5.2.b
# {'label': '5.2.b', 'm1': 18000.0, 'm2': 360.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.087, eta = 0.019, ds = 8.5e+18, T = -1.3e+08
# SNR,res 3.2786969083692763 0.06802551304731408
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 1.5249961005047117, 'eps_res': 23.385448780939278, 'eps': 23.385448780939278}
#
# Processing: 5.3.a
# {'label': '5.3.a', 'm1': 3000.0, 'm2': 300.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.016, eta = 0.083, ds = 1.6e+18, T = -1.3e+08
# SNR,res 7.934294850732648 0.031065627078851042
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.6301757237492003, 'eps_res': 10.679575917272935, 'eps': 10.679575917272935}
#
# Processing: 5.3.b
# {'label': '5.3.b', 'm1': 9000.0, 'm2': 900.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.047, eta = 0.083, ds = 8.5e+18, T = -1.3e+08
# SNR,res 4.091282457003595 0.06440216796949731
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 1.2221106835194995, 'eps_res': 22.13983449686887, 'eps': 22.13983449686887}
#
# Processing: 5.4.a
# {'label': '5.4.a', 'm1': 3000.0, 'm2': 3000.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.028, eta = 0.25, ds = 1.6e+18, T = -1.3e+08
# SNR,res 24.451864356598545 0.013184986705016456
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.2044833852781744, 'eps_res': 4.532664546801269, 'eps': 4.532664546801269}
#
# Processing: 5.4.b
# {'label': '5.4.b', 'm1': 9000.0, 'm2': 9000.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.085, eta = 0.25, ds = 8.5e+18, T = -1.3e+08
# SNR,res 11.834638951265955 0.10398267250125531
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.42248859644891396, 'eps_res': 35.746609660877844, 'eps': 35.746609660877844}
#
# Processing: 5.5.a
# {'label': '5.5.a', 'm1': 8.399999999999999, 'm2': 2.2399999999999998, 'dl': 13943971.392771732, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 5e-05, eta = 0.17, ds = 1.4e+18, T = -1.3e+08
# SNR,res 0.0036603090152504316 3.856807186483966
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 1366.0048862453514, 'eps_res': 1325.8726450875404, 'eps': 1366.0048862453514}
#
# Processing: 5.5.b
# {'label': '5.5.b', 'm1': 13.5, 'm2': 3.6, 'dl': 31312381.449641217, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 8.1e-05, eta = 0.17, ds = 3.2e+18, T = -1.3e+08
# SNR,res 0.003842166476306179 4.900861443074581
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 1301.349129673046, 'eps_res': 1684.7920599994063, 'eps': 1684.7920599994063}
#
# Processing: 5.5.c
# {'label': '5.5.c', 'm1': 6500.0, 'm2': 1.3, 'dl': 1572542.1375814416, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 50.0}}
# mtot = 0.031, eta = 0.0002, ds = 1.6e+17, T = -1.3e+08
# SNR,res 1.8338041874799655 0.030381572383796764
# {'resolution': 0.0029088820866572155, 'SNR': 50.0}
# {'eps_SNR': 27.265724629362182, 'eps_res': 10.444415235376622, 'eps': 27.265724629362182}
#
# Processing: 5.6.a
# {'label': '5.6.a', 'm1': 6500000.0, 'm2': 6500.0, 'dl': 53469364.83606955, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 20.0}}
# mtot =  31, eta = 0.001, ds = 5.5e+18, T = -1.3e+08
# SNR,res 67.23795835543785 0.007455834654904639
# {'resolution': 0.0029088820866572155, 'SNR': 20.0}
# {'eps_SNR': 0.29745103047708027, 'eps_res': 2.563127150840487, 'eps': 2.563127150840487}
#
# Processing mission Twin LISA
#
#
# Processing: 1.1.b
# {'label': '1.1.b', 'm1': 1.5750000000000002, 'm2': 1.5750000000000002, 'dl': 224582.2244309782, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot = 1.5e-05, eta = 0.25, ds = 2.3e+16, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.07733399614788679 0.2187858009116382
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 64.65461826695773, 'eps_res': 752.130180577581, 'eps': 752.130180577581}
#
# Processing: 1.1.c
# {'label': '1.1.c', 'm1': 3.0, 'm2': 3.0, 'dl': 6726141.242139786, 'type': 'chirp', 'conditions': {'resolution': 0.0001454441043328608, 'SNR': 5}}
# mtot = 2.8e-05, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.008506057099007043 2.6982545884949034
# {'resolution': 0.0001454441043328608, 'SNR': 5}
# {'eps_SNR': 587.8164162081249, 'eps_res': 18551.831996708, 'eps': 18551.831996708}
#
# Processing: 1.1.d
# {'label': '1.1.d', 'm1': 31.5, 'm2': 31.5, 'dl': 231610636.3389375, 'type': 'chirp', 'conditions': {'resolution': 2.9088820866572157e-05, 'SNR': 5}}
# mtot = 0.0003, eta = 0.25, ds = 2.4e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.014612028316750644 6.546034474687461
# {'resolution': 2.9088820866572157e-05, 'SNR': 5}
# {'eps_SNR': 342.18384276385507, 'eps_res': 225036.08876803707, 'eps': 225036.08876803707}
#
# Processing: 1.1.e
# {'label': '1.1.e', 'm1': 16.5, 'm2': 16.5, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 4.84813681109536e-06, 'SNR': 5}}
# mtot = 0.00016, eta = 0.25, ds = 1.1e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.011081834604030748 5.861530310127891
# {'resolution': 4.84813681109536e-06, 'SNR': 5}
# {'eps_SNR': 451.1888309704037, 'eps_res': 1209027.413730012, 'eps': 1209027.413730012}
#
# Processing: 1.2.b
# {'label': '1.2.b', 'm1': 1.7999999999999998, 'm2': 12.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot = 6.5e-05, eta = 0.11, ds = 1e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.11133257344165857 0.2844137705082256
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 44.91048617159777, 'eps_res': 977.7425211314213, 'eps': 977.7425211314213}
#
# Processing: 1.3.b
# {'label': '1.3.b', 'm1': 36.0, 'm2': 36.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot = 0.00034, eta = 0.25, ds = 1e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 4.206013614581168 0.02842600304820034
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 1.188774088287847, 'eps_res': 97.72140018527357, 'eps': 97.72140018527357}
#
# Processing: 1.3.c
# {'label': '1.3.c', 'm1': 60.0, 'm2': 60.0, 'dl': 6726141.242139786, 'type': 'chirp', 'conditions': {'resolution': 0.0001454441043328608, 'SNR': 5}}
# mtot = 0.00057, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 1.3436673867196116 0.10375943412302932
# {'resolution': 0.0001454441043328608, 'SNR': 5}
# {'eps_SNR': 3.7211590081134935, 'eps_res': 713.3973191898334, 'eps': 713.3973191898334}
#
# Processing: 1.3.d
# {'label': '1.3.d', 'm1': 630.0, 'm2': 630.0, 'dl': 231610636.3389375, 'type': 'chirp', 'conditions': {'resolution': 2.9088820866572157e-05, 'SNR': 5}}
# mtot = 0.006, eta = 0.25, ds = 2.4e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.7690953399131494 0.5610970620563026
# {'resolution': 2.9088820866572157e-05, 'SNR': 5}
# {'eps_SNR': 6.50114457924635, 'eps_res': 19289.09613180971, 'eps': 19289.09613180971}
#
# Processing: 1.3.e
# {'label': '1.3.e', 'm1': 330.0, 'm2': 330.0, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 4.84813681109536e-06, 'SNR': 5}}
# mtot = 0.0031, eta = 0.25, ds = 1.1e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 0.8346313233208142 0.4235308914661849
# {'resolution': 4.84813681109536e-06, 'SNR': 5}
# {'eps_SNR': 5.990669005934382, 'eps_res': 87359.51726793262, 'eps': 87359.51726793262}
#
# Processing: 2.1.b
# {'label': '2.1.b', 'm1': 2000000.0, 'm2': 2000000.0, 'dl': 6726141.242139786, 'type': 'chirp', 'timecut': 180.0, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# mtot =  19, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 20654.911559334036 0.00531299466082749
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 0.00024207317400690978, 'eps_res': 18.26473023845733, 'eps': 18.26473023845733}
#
# Processing: 2.1.c
# {'label': '2.1.c', 'm1': 2000000.0, 'm2': 2000000.0, 'dl': 6726141.242139786, 'type': 'chirp', 'conditions': {'resolution': 0.0001454441043328608, 'SNR': 5}}
# mtot =  19, eta = 0.25, ds = 6.9e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 20654.911559334036 1.5950446801158678e-05
# {'resolution': 0.0001454441043328608, 'SNR': 5}
# {'eps_SNR': 0.00024207317400690978, 'eps_res': 0.10966719396652043, 'eps': 0.10966719396652043}
#
# Processing: 2.1.d
# {'label': '2.1.d', 'm1': 21000000.0, 'm2': 21000000.0, 'dl': 231610636.3389375, 'type': 'chirp', 'conditions': {'resolution': 2.9088820866572157e-05, 'SNR': 5}}
# mtot = 2e+02, eta = 0.25, ds = 2.4e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# SNR,res 172.10249809105116 0.020082365931100306
# ...
# mtot =  14, eta = 0.25, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 10570.796643709935 0.005020080784628265
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': 0.0004730012475431744, 'eps_res': 17.257766506435342, 'eps': 17.257766506435342}
#
# Processing: 2.3.b
# {'label': '2.3.b', 'm1': 1500000.0, 'm2': 1500000.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  14, eta = 0.25, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 10570.796643709935 0.005020080784628265
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.0004730012475431744, 'eps_res': 5.752588835478447, 'eps': 5.752588835478447}
#
# Processing: 3.1.a
# {'label': '3.1.a', 'm1': 150.0, 'm2': 150000000.0, 'dl': 2874104.125862455, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot = 7.1e+02, eta = 1e-06, ds = 3e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.2.a
# {'label': '3.2.a', 'm1': 1.2, 'm2': 12000000.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  57, eta = 1e-07, ds = 1e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.2.b
# {'label': '3.2.b', 'm1': 1.2, 'm2': 12000000.0, 'dl': 991644.8422591747, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  57, eta = 1e-07, ds = 1e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.3.a
# {'label': '3.3.a', 'm1': 25.0, 'm2': 1250000.0, 'dl': 11129368.800256329, 'type': 'chirp', 'timecut': 15.0, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot = 5.9, eta = 2e-05, ds = 1.1e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 88.88317159767372 nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.0562536182060684, 'eps_res': nan, 'eps': nan}
#
# Processing: 3.3.b
# {'label': '3.3.b', 'm1': 25.0, 'm2': 1250000.0, 'dl': 11129368.800256329, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot = 5.9, eta = 2e-05, ds = 1.1e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 88.88317159767372 0.000768737215479634
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.0562536182060684, 'eps_res': 0.8809079600324393, 'eps': 0.8809079600324393}
#
# Processing: 3.3.c
# {'label': '3.3.c', 'm1': 65.0, 'm2': 3250000.0, 'dl': 53469364.83606955, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# mtot =  15, eta = 2e-05, ds = 5.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 17.51114205364404 0.10583196341746766
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': 0.28553249038143164, 'eps_res': 121.27449682807642, 'eps': 121.27449682807642}
#
# Processing: 3.3.d
# {'label': '3.3.d', 'm1': 76.0, 'm2': 3800000.0, 'dl': 66123392.56646311, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 100.0}}
# mtot =  18, eta = 2e-05, ds = 6.8e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 12.998308431876353 0.16125239010218337
# {'resolution': 0.0008726646259971648, 'SNR': 100.0}
# {'eps_SNR': 7.693308750449818, 'eps_res': 184.78162778504472, 'eps': 184.78162778504472}
#
# Processing: 3.3.e
# {'label': '3.3.e', 'm1': 110.0, 'm2': 5500000.0, 'dl': 106554395.34780096, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 100.0}}
# mtot =  26, eta = 2e-05, ds = 1.1e+19, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 6.349764702087147 0.44672234180976855
# {'resolution': 0.0008726646259971648, 'SNR': 100.0}
# {'eps_SNR': 15.7486150576777, 'eps_res': 511.90609599800587, 'eps': 511.90609599800587}
#
# Processing: 3.4.a
# {'label': '3.4.a', 'm1': 1375000.0, 'm2': 1.65, 'dl': 13467605.79493649, 'type': 'chirp', 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 100.0}}
# mtot = 6.5, eta = 1.2e-06, ds = 1.4e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 18.732134968532424 0.008524669429390635
# {'resolution': 0.0008726646259971648, 'SNR': 100.0}
# {'eps_SNR': 5.338419788667289, 'eps_res': 9.768551600965582, 'eps': 9.768551600965582}
#
# Processing: 4.1.a
# {'label': '4.1.a', 'm1': 0.72, 'm2': 0.72, 'dl': 991644.8422591747, 'type': 'CW', 'f0': 0.0005, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# snrt: len,min,max= 1000 3.3800563252376163e-10 3.3800563252376163e-10
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 4.1.b
# {'label': '4.1.b', 'm1': 0.600135, 'm2': 0.600135, 'dl': 973.2431716602136, 'type': 'CW', 'f0': 0.00057, 'conditions': {'resolution': 0.0008726646259971648, 'SNR': 5}}
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# snrt: len,min,max= 1000 4.4563008796257586e-07 4.4563008796257586e-07
# SNR,res nan nan
# {'resolution': 0.0008726646259971648, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 4.1.c
# {'label': '4.1.c', 'm1': 1.2, 'm2': 1.2, 'dl': 6726141.242139786, 'type': 'CW', 'f0': 0.000368, 'conditions': {'resolution': 0.0002908882086657216, 'SNR': 5}}
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# snrt: len,min,max= 1000 2.9067103764310292e-11 2.9067103764310292e-11
# SNR,res nan nan
# {'resolution': 0.0002908882086657216, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 4.1.d
# {'label': '4.1.d', 'm1': 1.7999999999999998, 'm2': 1.7999999999999998, 'dl': 15875191.123148063, 'type': 'CW', 'f0': 0.000286, 'conditions': {'resolution': 9.69627362219072e-05, 'SNR': 5}}
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# snrt: len,min,max= 1000 7.652566716163469e-12 7.652566716163469e-12
# SNR,res nan nan
# {'resolution': 9.69627362219072e-05, 'SNR': 5}
# {'eps_SNR': nan, 'eps_res': nan, 'eps': nan}
#
# Processing: 5.1.a
# {'label': '5.1.a', 'm1': 110.00000000000001, 'm2': 11.0, 'dl': 465280.59136148746, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.00057, eta = 0.083, ds = 4.8e+16, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 32.10237838894588 0.0013622951356491591
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.15575169974700995, 'eps_res': 0.46832257034339286, 'eps': 0.46832257034339286}
#
# Processing: 5.1.b
# {'label': '5.1.b', 'm1': 300.0, 'm2': 30.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.0016, eta = 0.083, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 3.3438576995798304 0.023052704720867012
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 1.4952789410351615, 'eps_res': 7.924936121201931, 'eps': 7.924936121201931}
#
# Processing: 5.1.c
# {'label': '5.1.c', 'm1': 900.0, 'm2': 90.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.0047, eta = 0.083, ds = 8.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 2.1194544269515876 0.053864899796558105
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 2.35909766986191, 'eps_res': 18.517388533427198, 'eps': 18.517388533427198}
#
# Processing: 5.1.d
# {'label': '5.1.d', 'm1': 100100.0, 'm2': 10010.0, 'dl': 13997333920.647652, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.52, eta = 0.083, ds = 1.4e+21, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 0.6835121088928189 10.58088396261775
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 7.315159358477506, 'eps_res': 3637.439967453933, 'eps': 3637.439967453933}
#
# Processing: 5.2.a
# {'label': '5.2.a', 'm1': 6000.0, 'm2': 120.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.029, eta = 0.019, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 25.772510582742104 0.004262088032703381
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.19400515847874444, 'eps_res': 1.4651979371227184, 'eps': 1.4651979371227184}
#
# Processing: 5.2.b
# {'label': '5.2.b', 'm1': 18000.0, 'm2': 360.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.087, eta = 0.019, ds = 8.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 12.523097920165577 0.02787190514440317
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.39926222983121823, 'eps_res': 9.581655190579614, 'eps': 9.581655190579614}
#
# Processing: 5.3.a
# {'label': '5.3.a', 'm1': 3000.0, 'm2': 300.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.016, eta = 0.083, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 32.094898958143204 0.004490683506683182
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.15578799629563522, 'eps_res': 1.54378327237173, 'eps': 1.54378327237173}
#
# Processing: 5.3.b
# {'label': '5.3.b', 'm1': 9000.0, 'm2': 900.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.047, eta = 0.083, ds = 8.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 15.52492217002516 0.036123879242647136
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.3220628061925992, 'eps_res': 12.418474921463531, 'eps': 12.418474921463531}
#
# Processing: 5.4.a
# {'label': '5.4.a', 'm1': 3000.0, 'm2': 3000.0, 'dl': 15875191.123148063, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.028, eta = 0.25, ds = 1.6e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 92.52268513146258 0.008396147282042767
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.054040800835985864, 'eps_res': 2.8863828205877273, 'eps': 2.8863828205877273}
#
# Processing: 5.4.b
# {'label': '5.4.b', 'm1': 9000.0, 'm2': 9000.0, 'dl': 82565701.74638993, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 0.085, eta = 0.25, ds = 8.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 44.46571993310117 0.07222710132675572
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 0.1124461721866309, 'eps_res': 24.82984843492111, 'eps': 24.82984843492111}
#
# Processing: 5.5.a
# {'label': '5.5.a', 'm1': 8.399999999999999, 'm2': 2.2399999999999998, 'dl': 13943971.392771732, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 5e-05, eta = 0.17, ds = 1.4e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 0.06633364782682509 0.20341222513724522
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 75.37652705386147, 'eps_res': 69.92797201037439, 'eps': 75.37652705386147}
#
# Processing: 5.5.b
# {'label': '5.5.b', 'm1': 13.5, 'm2': 3.6, 'dl': 31312381.449641217, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 5}}
# mtot = 8.1e-05, eta = 0.17, ds = 3.2e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 0.05903286116920594 0.3020505307005448
# {'resolution': 0.0029088820866572155, 'SNR': 5}
# {'eps_SNR': 84.698588226454, 'eps_res': 103.83732365296751, 'eps': 103.83732365296751}
#
# Processing: 5.5.c
# {'label': '5.5.c', 'm1': 6500.0, 'm2': 1.3, 'dl': 1572542.1375814416, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 50.0}}
# mtot = 0.031, eta = 0.0002, ds = 1.6e+17, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 15.317784704120957 0.003242301418818539
# {'resolution': 0.0029088820866572155, 'SNR': 50.0}
# {'eps_SNR': 3.264179577256263, 'eps_res': 1.1146211232454861, 'eps': 3.264179577256263}
#
# Processing: 5.6.a
# {'label': '5.6.a', 'm1': 6500000.0, 'm2': 6500.0, 'dl': 53469364.83606955, 'type': 'chirp', 'conditions': {'resolution': 0.0029088820866572155, 'SNR': 20.0}}
# mtot =  31, eta = 0.001, ds = 5.5e+18, T = -1.3e+08
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14
# SNR,res 79.10747705086229 0.006397299688659181
# {'resolution': 0.0029088820866572155, 'SNR': 20.0}
# {'eps_SNR': 0.2528206023703798, 'eps_res': 2.19922963464316, 'eps': 2.19922963464316}

# %% [markdown]
# ### Show assessments

# %%
#Make a dataframe with the results
objectiveNames=df['provisional POC label'].values
data=np.zeros((len(obs),len(missions)))
for i,mission in enumerate(missions):
    for j,ob in enumerate(mission['obs']):
        #print(missionNames[i],objectiveNames[j],ob['assessment'])
        data[j,i]=ob['assessment'].get('eps',None)

adf = pd.DataFrame(data,
                  index=objectiveNames,
                  columns=missionNames)
#adf=adf.dropna()
def shrink():
    return [dict(selector="th",
                 props=[("font-size", "6pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")])
]
def zoom():
    return [
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]
s=adf.style.background_gradient(vmin=0.1,vmax=10,cmap='RdYlGn_r').set_properties(**{'max-width': '120px', 'font-size': '6pt'})
#s=s.set_table_styles(shrink())
s=s.set_table_styles(shrink()+zoom())
s=s.set_caption("Net performance")
display(s)
if True:
    dates = date.today().strftime("%Y_%m_%d")
    outfile=datadir+'ScoredObservations_net_'+dates+'.csv'
    adf.to_csv(outfile,index=False)
    print('Wrote to file:',outfile)
# Out:
# <style type="text/css">
# #T_bfd3d_ th {
#   font-size: 6pt;
# }
# #T_bfd3d_ td {
#   padding: 0em 0em;
# }
# #T_bfd3d_ th:hover {
#   font-size: 12pt;
# }
# #T_bfd3d_ tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# #T_bfd3d_row0_col0, #T_bfd3d_row0_col1, #T_bfd3d_row0_col3, #T_bfd3d_row0_col4, #T_bfd3d_row0_col6, #T_bfd3d_row0_col7, #T_bfd3d_row4_col0, #T_bfd3d_row4_col1, #T_bfd3d_row4_col3, #T_bfd3d_row4_col4, #T_bfd3d_row4_col6, #T_bfd3d_row4_col7, #T_bfd3d_row5_col0, #T_bfd3d_row5_col1, #T_bfd3d_row5_col3, #T_bfd3d_row5_col4, #T_bfd3d_row5_col6, #T_bfd3d_row5_col7, #T_bfd3d_row9_col0, #T_bfd3d_row9_col1, #T_bfd3d_row9_col3, #T_bfd3d_row9_col4, #T_bfd3d_row9_col6, #T_bfd3d_row9_col7, #T_bfd3d_row15_col0, #T_bfd3d_row15_col1, #T_bfd3d_row15_col2, #T_bfd3d_row15_col3, #T_bfd3d_row15_col4, #T_bfd3d_row15_col5, #T_bfd3d_row15_col6, #T_bfd3d_row15_col7, #T_bfd3d_row16_col0, #T_bfd3d_row16_col1, #T_bfd3d_row16_col2, #T_bfd3d_row16_col3, #T_bfd3d_row16_col4, #T_bfd3d_row16_col5, #T_bfd3d_row16_col6, #T_bfd3d_row16_col7, #T_bfd3d_row17_col0, #T_bfd3d_row17_col1, #T_bfd3d_row17_col2, #T_bfd3d_row17_col3, #T_bfd3d_row17_col4, #T_bfd3d_row17_col5, #T_bfd3d_row17_col6, #T_bfd3d_row17_col7, #T_bfd3d_row18_col0, #T_bfd3d_row18_col1, #T_bfd3d_row18_col3, #T_bfd3d_row18_col4, #T_bfd3d_row18_col6, #T_bfd3d_row18_col7, #T_bfd3d_row24_col0, #T_bfd3d_row24_col1, #T_bfd3d_row24_col2, #T_bfd3d_row24_col3, #T_bfd3d_row24_col4, #T_bfd3d_row24_col5, #T_bfd3d_row24_col6, #T_bfd3d_row24_col7, #T_bfd3d_row25_col0, #T_bfd3d_row25_col1, #T_bfd3d_row25_col2, #T_bfd3d_row25_col3, #T_bfd3d_row25_col4, #T_bfd3d_row25_col5, #T_bfd3d_row25_col6, #T_bfd3d_row25_col7, #T_bfd3d_row26_col0, #T_bfd3d_row26_col1, #T_bfd3d_row26_col2, #T_bfd3d_row26_col3, #T_bfd3d_row26_col4, #T_bfd3d_row26_col5, #T_bfd3d_row26_col6, #T_bfd3d_row26_col7, #T_bfd3d_row27_col0, #T_bfd3d_row27_col1, #T_bfd3d_row27_col2, #T_bfd3d_row27_col3, #T_bfd3d_row27_col4, #T_bfd3d_row27_col5, #T_bfd3d_row27_col6, #T_bfd3d_row27_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row0_col2, #T_bfd3d_row0_col5, #T_bfd3d_row1_col0, #T_bfd3d_row1_col1, #T_bfd3d_row1_col2, #T_bfd3d_row1_col3, #T_bfd3d_row1_col4, #T_bfd3d_row1_col5, #T_bfd3d_row1_col6, #T_bfd3d_row1_col7, #T_bfd3d_row2_col0, #T_bfd3d_row2_col1, #T_bfd3d_row2_col2, #T_bfd3d_row2_col3, #T_bfd3d_row2_col4, #T_bfd3d_row2_col5, #T_bfd3d_row2_col6, #T_bfd3d_row2_col7, #T_bfd3d_row3_col0, #T_bfd3d_row3_col1, #T_bfd3d_row3_col2, #T_bfd3d_row3_col3, #T_bfd3d_row3_col4, #T_bfd3d_row3_col5, #T_bfd3d_row3_col6, #T_bfd3d_row3_col7, #T_bfd3d_row4_col2, #T_bfd3d_row4_col5, #T_bfd3d_row5_col2, #T_bfd3d_row6_col0, #T_bfd3d_row6_col1, #T_bfd3d_row6_col2, #T_bfd3d_row6_col3, #T_bfd3d_row6_col4, #T_bfd3d_row6_col5, #T_bfd3d_row6_col6, #T_bfd3d_row6_col7, #T_bfd3d_row7_col0, #T_bfd3d_row7_col1, #T_bfd3d_row7_col2, #T_bfd3d_row7_col3, #T_bfd3d_row7_col4, #T_bfd3d_row7_col5, #T_bfd3d_row7_col6, #T_bfd3d_row7_col7, #T_bfd3d_row8_col0, #T_bfd3d_row8_col1, #T_bfd3d_row8_col2, #T_bfd3d_row8_col3, #T_bfd3d_row8_col4, #T_bfd3d_row8_col5, #T_bfd3d_row8_col6, #T_bfd3d_row8_col7, #T_bfd3d_row9_col2, #T_bfd3d_row10_col1, #T_bfd3d_row10_col6, #T_bfd3d_row10_col7, #T_bfd3d_row11_col0, #T_bfd3d_row11_col1, #T_bfd3d_row11_col2, #T_bfd3d_row11_col3, #T_bfd3d_row11_col5, #T_bfd3d_row11_col6, #T_bfd3d_row11_col7, #T_bfd3d_row12_col0, #T_bfd3d_row12_col1, #T_bfd3d_row12_col2, #T_bfd3d_row12_col3, #T_bfd3d_row12_col4, #T_bfd3d_row12_col6, #T_bfd3d_row12_col7, #T_bfd3d_row13_col1, #T_bfd3d_row13_col6, #T_bfd3d_row13_col7, #T_bfd3d_row18_col2, #T_bfd3d_row20_col0, #T_bfd3d_row20_col1, #T_bfd3d_row20_col2, #T_bfd3d_row20_col3, #T_bfd3d_row20_col4, #T_bfd3d_row20_col6, #T_bfd3d_row20_col7, #T_bfd3d_row21_col0, #T_bfd3d_row21_col1, #T_bfd3d_row21_col2, #T_bfd3d_row21_col3, #T_bfd3d_row21_col4, #T_bfd3d_row21_col6, #T_bfd3d_row21_col7, #T_bfd3d_row22_col0, #T_bfd3d_row22_col1, #T_bfd3d_row22_col2, #T_bfd3d_row22_col3, #T_bfd3d_row22_col4, #T_bfd3d_row22_col5, #T_bfd3d_row22_col6, #T_bfd3d_row22_col7, #T_bfd3d_row23_col0, #T_bfd3d_row23_col1, #T_bfd3d_row23_col2, #T_bfd3d_row23_col6, #T_bfd3d_row29_col0, #T_bfd3d_row29_col1, #T_bfd3d_row29_col2, #T_bfd3d_row29_col3, #T_bfd3d_row29_col4, #T_bfd3d_row30_col0, #T_bfd3d_row30_col1, #T_bfd3d_row30_col2, #T_bfd3d_row30_col3, #T_bfd3d_row30_col4, #T_bfd3d_row30_col6, #T_bfd3d_row30_col7, #T_bfd3d_row31_col0, #T_bfd3d_row31_col1, #T_bfd3d_row31_col2, #T_bfd3d_row31_col3, #T_bfd3d_row31_col4, #T_bfd3d_row31_col5, #T_bfd3d_row31_col6, #T_bfd3d_row31_col7, #T_bfd3d_row32_col1, #T_bfd3d_row32_col2, #T_bfd3d_row33_col0, #T_bfd3d_row33_col1, #T_bfd3d_row33_col2, #T_bfd3d_row33_col6, #T_bfd3d_row34_col1, #T_bfd3d_row34_col2, #T_bfd3d_row35_col0, #T_bfd3d_row35_col1, #T_bfd3d_row35_col2, #T_bfd3d_row35_col6, #T_bfd3d_row35_col7, #T_bfd3d_row37_col0, #T_bfd3d_row37_col1, #T_bfd3d_row37_col6, #T_bfd3d_row37_col7, #T_bfd3d_row38_col0, #T_bfd3d_row38_col1, #T_bfd3d_row38_col2, #T_bfd3d_row38_col3, #T_bfd3d_row38_col4, #T_bfd3d_row38_col5, #T_bfd3d_row38_col6, #T_bfd3d_row38_col7, #T_bfd3d_row39_col0, #T_bfd3d_row39_col1, #T_bfd3d_row39_col2, #T_bfd3d_row39_col3, #T_bfd3d_row39_col4, #T_bfd3d_row39_col5, #T_bfd3d_row39_col6, #T_bfd3d_row39_col7, #T_bfd3d_row40_col0, #T_bfd3d_row40_col1, #T_bfd3d_row40_col2, #T_bfd3d_row40_col3, #T_bfd3d_row40_col4, #T_bfd3d_row40_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row5_col5, #T_bfd3d_row32_col4 {
#   background-color: #cbe982;
#   color: #000000;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row9_col5, #T_bfd3d_row19_col3 {
#   background-color: #07753e;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row10_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row10_col2, #T_bfd3d_row10_col3, #T_bfd3d_row10_col4, #T_bfd3d_row10_col5, #T_bfd3d_row13_col2, #T_bfd3d_row13_col4, #T_bfd3d_row13_col5, #T_bfd3d_row14_col2, #T_bfd3d_row14_col3, #T_bfd3d_row14_col4, #T_bfd3d_row14_col5, #T_bfd3d_row19_col5, #T_bfd3d_row36_col5, #T_bfd3d_row41_col4, #T_bfd3d_row41_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row11_col4 {
#   background-color: #f47044;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row12_col5 {
#   background-color: #bb1526;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row13_col0 {
#   background-color: #de402e;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row13_col3, #T_bfd3d_row37_col5 {
#   background-color: #016a38;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row14_col0, #T_bfd3d_row19_col1, #T_bfd3d_row36_col7 {
#   background-color: #9bd469;
#   color: #000000;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row14_col1 {
#   background-color: #c7e77f;
#   color: #000000;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row14_col6 {
#   background-color: #fdbf6f;
#   color: #000000;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row14_col7 {
#   background-color: #fee999;
#   color: #000000;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row18_col5, #T_bfd3d_row19_col6 {
#   background-color: #16914d;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row19_col0 {
#   background-color: #70c164;
#   color: #000000;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row19_col2 {
#   background-color: #a9da6c;
#   color: #000000;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row19_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row19_col7 {
#   background-color: #148e4b;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row20_col5 {
#   background-color: #f5fbb2;
#   color: #000000;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row21_col5 {
#   background-color: #fecc7b;
#   color: #000000;
#   max-width: 120px;
#   font-size: 6pt;
# }
# #T_bfd3d_row23_col3 {
#   background-col
# Wrote to file: ../Data/ScoredObservations_net_2022_06_23.csv

# %%
#Make a dataframe with the results
objectiveNames=df['provisional POC label'].values
data=np.zeros((len(obs),len(missions)))
for i,mission in enumerate(missions):
    for j,ob in enumerate(mission['obs']):
        #print(missionNames[i],objectiveNames[j],ob['assessment'])
        data[j,i]=ob['assessment'].get('eps_res',None)

adf = pd.DataFrame(data,
                  index=objectiveNames,
                  columns=missionNames)
#adf=adf.dropna()
def shrink():
    return [dict(selector="th",
                 props=[("font-size", "6pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")])
]
def zoom():
    return [
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]
s=adf.style.background_gradient(vmin=0.1,vmax=10,cmap='RdYlGn_r').set_properties(**{'max-width': '120px', 'font-size': '8pt'})
#s=s.set_table_styles(shrink())
s=s.set_table_styles(shrink()+zoom())
s=s.set_caption("Resolution performance")
display(s)
if True:
    dates = date.today().strftime("%Y_%m_%d")
    outfile=datadir+'ScoredObservations_res_'+dates+'.csv'
    adf.to_csv(outfile,index=False)
    print('Wrote to file:',outfile)
# Out:
# <style type="text/css">
# #T_e1fdf_ th {
#   font-size: 6pt;
# }
# #T_e1fdf_ td {
#   padding: 0em 0em;
# }
# #T_e1fdf_ th:hover {
#   font-size: 12pt;
# }
# #T_e1fdf_ tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# #T_e1fdf_row0_col0, #T_e1fdf_row0_col1, #T_e1fdf_row0_col3, #T_e1fdf_row0_col4, #T_e1fdf_row0_col6, #T_e1fdf_row0_col7, #T_e1fdf_row4_col0, #T_e1fdf_row4_col1, #T_e1fdf_row4_col3, #T_e1fdf_row4_col4, #T_e1fdf_row4_col6, #T_e1fdf_row4_col7, #T_e1fdf_row5_col0, #T_e1fdf_row5_col1, #T_e1fdf_row5_col3, #T_e1fdf_row5_col4, #T_e1fdf_row5_col6, #T_e1fdf_row5_col7, #T_e1fdf_row9_col0, #T_e1fdf_row9_col1, #T_e1fdf_row9_col3, #T_e1fdf_row9_col4, #T_e1fdf_row9_col6, #T_e1fdf_row9_col7, #T_e1fdf_row15_col0, #T_e1fdf_row15_col1, #T_e1fdf_row15_col2, #T_e1fdf_row15_col3, #T_e1fdf_row15_col4, #T_e1fdf_row15_col5, #T_e1fdf_row15_col6, #T_e1fdf_row15_col7, #T_e1fdf_row16_col0, #T_e1fdf_row16_col1, #T_e1fdf_row16_col2, #T_e1fdf_row16_col3, #T_e1fdf_row16_col4, #T_e1fdf_row16_col5, #T_e1fdf_row16_col6, #T_e1fdf_row16_col7, #T_e1fdf_row17_col0, #T_e1fdf_row17_col1, #T_e1fdf_row17_col2, #T_e1fdf_row17_col3, #T_e1fdf_row17_col4, #T_e1fdf_row17_col5, #T_e1fdf_row17_col6, #T_e1fdf_row17_col7, #T_e1fdf_row18_col0, #T_e1fdf_row18_col1, #T_e1fdf_row18_col3, #T_e1fdf_row18_col4, #T_e1fdf_row18_col6, #T_e1fdf_row18_col7, #T_e1fdf_row24_col0, #T_e1fdf_row24_col1, #T_e1fdf_row24_col2, #T_e1fdf_row24_col3, #T_e1fdf_row24_col4, #T_e1fdf_row24_col5, #T_e1fdf_row24_col6, #T_e1fdf_row24_col7, #T_e1fdf_row25_col0, #T_e1fdf_row25_col1, #T_e1fdf_row25_col2, #T_e1fdf_row25_col3, #T_e1fdf_row25_col4, #T_e1fdf_row25_col5, #T_e1fdf_row25_col6, #T_e1fdf_row25_col7, #T_e1fdf_row26_col0, #T_e1fdf_row26_col1, #T_e1fdf_row26_col2, #T_e1fdf_row26_col3, #T_e1fdf_row26_col4, #T_e1fdf_row26_col5, #T_e1fdf_row26_col6, #T_e1fdf_row26_col7, #T_e1fdf_row27_col0, #T_e1fdf_row27_col1, #T_e1fdf_row27_col2, #T_e1fdf_row27_col3, #T_e1fdf_row27_col4, #T_e1fdf_row27_col5, #T_e1fdf_row27_col6, #T_e1fdf_row27_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row0_col2, #T_e1fdf_row0_col5, #T_e1fdf_row1_col0, #T_e1fdf_row1_col1, #T_e1fdf_row1_col2, #T_e1fdf_row1_col3, #T_e1fdf_row1_col4, #T_e1fdf_row1_col5, #T_e1fdf_row1_col6, #T_e1fdf_row1_col7, #T_e1fdf_row2_col0, #T_e1fdf_row2_col1, #T_e1fdf_row2_col2, #T_e1fdf_row2_col3, #T_e1fdf_row2_col4, #T_e1fdf_row2_col5, #T_e1fdf_row2_col6, #T_e1fdf_row2_col7, #T_e1fdf_row3_col0, #T_e1fdf_row3_col1, #T_e1fdf_row3_col2, #T_e1fdf_row3_col3, #T_e1fdf_row3_col4, #T_e1fdf_row3_col5, #T_e1fdf_row3_col6, #T_e1fdf_row3_col7, #T_e1fdf_row4_col2, #T_e1fdf_row4_col5, #T_e1fdf_row5_col2, #T_e1fdf_row6_col0, #T_e1fdf_row6_col1, #T_e1fdf_row6_col2, #T_e1fdf_row6_col3, #T_e1fdf_row6_col4, #T_e1fdf_row6_col5, #T_e1fdf_row6_col6, #T_e1fdf_row6_col7, #T_e1fdf_row7_col0, #T_e1fdf_row7_col1, #T_e1fdf_row7_col2, #T_e1fdf_row7_col3, #T_e1fdf_row7_col4, #T_e1fdf_row7_col5, #T_e1fdf_row7_col6, #T_e1fdf_row7_col7, #T_e1fdf_row8_col0, #T_e1fdf_row8_col1, #T_e1fdf_row8_col2, #T_e1fdf_row8_col3, #T_e1fdf_row8_col4, #T_e1fdf_row8_col5, #T_e1fdf_row8_col6, #T_e1fdf_row8_col7, #T_e1fdf_row9_col2, #T_e1fdf_row10_col1, #T_e1fdf_row10_col6, #T_e1fdf_row10_col7, #T_e1fdf_row11_col0, #T_e1fdf_row11_col1, #T_e1fdf_row11_col2, #T_e1fdf_row11_col3, #T_e1fdf_row11_col5, #T_e1fdf_row11_col6, #T_e1fdf_row11_col7, #T_e1fdf_row12_col0, #T_e1fdf_row12_col1, #T_e1fdf_row12_col2, #T_e1fdf_row12_col3, #T_e1fdf_row12_col4, #T_e1fdf_row12_col6, #T_e1fdf_row12_col7, #T_e1fdf_row13_col1, #T_e1fdf_row13_col6, #T_e1fdf_row13_col7, #T_e1fdf_row18_col2, #T_e1fdf_row20_col0, #T_e1fdf_row20_col1, #T_e1fdf_row20_col2, #T_e1fdf_row20_col3, #T_e1fdf_row20_col4, #T_e1fdf_row20_col6, #T_e1fdf_row20_col7, #T_e1fdf_row21_col0, #T_e1fdf_row21_col1, #T_e1fdf_row21_col2, #T_e1fdf_row21_col3, #T_e1fdf_row21_col4, #T_e1fdf_row21_col6, #T_e1fdf_row21_col7, #T_e1fdf_row22_col0, #T_e1fdf_row22_col1, #T_e1fdf_row22_col2, #T_e1fdf_row22_col3, #T_e1fdf_row22_col4, #T_e1fdf_row22_col5, #T_e1fdf_row22_col6, #T_e1fdf_row22_col7, #T_e1fdf_row23_col0, #T_e1fdf_row23_col1, #T_e1fdf_row23_col2, #T_e1fdf_row23_col6, #T_e1fdf_row29_col0, #T_e1fdf_row29_col1, #T_e1fdf_row29_col2, #T_e1fdf_row29_col3, #T_e1fdf_row29_col4, #T_e1fdf_row30_col0, #T_e1fdf_row30_col1, #T_e1fdf_row30_col2, #T_e1fdf_row30_col3, #T_e1fdf_row30_col4, #T_e1fdf_row30_col6, #T_e1fdf_row30_col7, #T_e1fdf_row31_col0, #T_e1fdf_row31_col1, #T_e1fdf_row31_col2, #T_e1fdf_row31_col3, #T_e1fdf_row31_col4, #T_e1fdf_row31_col6, #T_e1fdf_row31_col7, #T_e1fdf_row32_col1, #T_e1fdf_row32_col2, #T_e1fdf_row33_col0, #T_e1fdf_row33_col1, #T_e1fdf_row33_col2, #T_e1fdf_row33_col6, #T_e1fdf_row34_col1, #T_e1fdf_row34_col2, #T_e1fdf_row35_col0, #T_e1fdf_row35_col1, #T_e1fdf_row35_col2, #T_e1fdf_row35_col6, #T_e1fdf_row35_col7, #T_e1fdf_row37_col0, #T_e1fdf_row37_col1, #T_e1fdf_row37_col6, #T_e1fdf_row37_col7, #T_e1fdf_row38_col0, #T_e1fdf_row38_col1, #T_e1fdf_row38_col2, #T_e1fdf_row38_col3, #T_e1fdf_row38_col4, #T_e1fdf_row38_col5, #T_e1fdf_row38_col6, #T_e1fdf_row38_col7, #T_e1fdf_row39_col0, #T_e1fdf_row39_col1, #T_e1fdf_row39_col2, #T_e1fdf_row39_col3, #T_e1fdf_row39_col4, #T_e1fdf_row39_col5, #T_e1fdf_row39_col6, #T_e1fdf_row39_col7, #T_e1fdf_row40_col1, #T_e1fdf_row40_col2, #T_e1fdf_row40_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row5_col5, #T_e1fdf_row32_col4 {
#   background-color: #cbe982;
#   color: #000000;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row9_col5, #T_e1fdf_row19_col3, #T_e1fdf_row40_col5 {
#   background-color: #07753e;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row10_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row10_col2, #T_e1fdf_row10_col3, #T_e1fdf_row10_col4, #T_e1fdf_row10_col5, #T_e1fdf_row13_col2, #T_e1fdf_row13_col4, #T_e1fdf_row13_col5, #T_e1fdf_row14_col2, #T_e1fdf_row14_col3, #T_e1fdf_row14_col4, #T_e1fdf_row14_col5, #T_e1fdf_row19_col5, #T_e1fdf_row36_col5, #T_e1fdf_row41_col4, #T_e1fdf_row41_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row11_col4 {
#   background-color: #f47044;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row12_col5 {
#   background-color: #bb1526;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row13_col0 {
#   background-color: #de402e;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row13_col3, #T_e1fdf_row37_col5 {
#   background-color: #016a38;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row14_col0, #T_e1fdf_row19_col1, #T_e1fdf_row36_col7 {
#   background-color: #9bd469;
#   color: #000000;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row14_col1 {
#   background-color: #c7e77f;
#   color: #000000;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row14_col6 {
#   background-color: #fdbf6f;
#   color: #000000;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row14_col7 {
#   background-color: #fee999;
#   color: #000000;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row18_col5, #T_e1fdf_row19_col6 {
#   background-color: #16914d;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row19_col0 {
#   background-color: #70c164;
#   color: #000000;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row19_col2 {
#   background-color: #a9da6c;
#   color: #000000;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row19_col4 {
#   background-color: #04703b;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row19_col7 {
#   background-color: #148e4b;
#   color: #f1f1f1;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row20_col5 {
#   background-color: #f5fbb2;
#   color: #000000;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row21_col5 {
#   background-color: #fecc7b;
#   color: #000000;
#   max-width: 120px;
#   font-size: 8pt;
# }
# #T_e1fdf_row23_col3 {
#   background-color: #ddf191;
#   color: #000000;
#   max-width: 120px;
#   font-size:
# Wrote to file: ../Data/ScoredObservations_res_2022_06_23.csv

# %% [markdown]
# ### Make some plots

# %% [markdown]
# #### Plot sensitivity curves and waveform
# Here we scale the waveform by delta-f, which is probably not quite right

# %%
# sensitivity plot
#fig = plt.figure(figsize=(6,4),dpi=200)
f = np.logspace(-5,0,1000)
fig,axs=plt.subplots(len(missions),figsize=(6,4*len(missions)))
for i,mission in enumerate(missions):
    ax = axs[i]
    for ob in mission['obs']:
        if ob['source']['type']=='CW':continue
        if ob['assessment'].get('eps',10)>1:continue
        ax.plot(ob.get('f')[1:],np.abs(ob.get('h')[1:]**2)*np.diff(ob.get('f')),linestyle='-',label=ob.get('source').get('label'))
    
    ax.plot(f,metrics.makeSensitivity(f,mission),color = 'black', linewidth=2.0,linestyle='--',label='sensitivity')
    ax.set_title(mission['label'])
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.legend()
    ax.grid(True)

plt.xlabel(r'Frequency [Hz]')
plt.ylabel(r'Strain PSD [Hz$^{-1}$]')
plt.subplots_adjust()
plt.savefig('../plots/%s_source_sensitvities.png' % 'all')
# Out:
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 8.444165217362159e-10
# sqSn_shot: 2.764880922798791e-12
# QE: 0.8156855160078964
# P_Rx: 1.3031119162595927e-10
# sqSn_shot: 7.038237778863639e-12
# QE: 0.5599286380854205
# P_Rx: 9.083534705280001e-12
# sqSn_shot: 3.883447365388777e-11
# QE: 0.5599286380854205
# P_Rx: 9.947560526446235e-11
# sqSn_shot: 1.1735093873706993e-11
# QE: 0.8156855160078964
# P_Rx: 1.737482555012791e-05
# sqSn_shot: 1.927500798284336e-14

# %% [markdown]
# #### SNR as a function of time plot

# %%
# SNR of time plot
fig = plt.figure(figsize=(6,4),dpi=200)
#ax = fig.add_subplot(1,1,1)
fig,axs=plt.subplots(len(missions),figsize=(6,4*len(missions)))
for i,mission in enumerate(missions):
    ax = axs[i]
    for ob in mission['obs']:
        if ob['source']['type']=='CW':continue
        if ob['assessment'].get('eps',10)>1:continue
        ax.plot(-ob.get('t')*52/constants.year,ob.get('SNR of t'),linestyle='-',label=ob.get('source').get('label'))
        ax.set_title(mission['label'])
        ax.set_xscale('linear')
        ax.set_yscale('log')
        ax.legend()
        
#print(obs)
#plt.xlim([-ob.get('t')[0]*52/constants.year+4,-4])
#plt.title(ob.get('source').get('label'))
plt.xlabel('Time to merger [wks]')
plt.ylabel(r'SNR')
plt.subplots_adjust()
#plt.legend()
ax.grid(True)
#plt.savefig('../plots/%s_snr_v_t.png' % modelName)

# %% [markdown]
# #### Angular resolution as a function of time

# %%
# Angular resolution
# SNR of time plot
fig = plt.figure(figsize=(6,4),dpi=200)
#ax = fig.add_subplot(1,1,1)
fig,axs=plt.subplots(len(missions),figsize=(6,4*len(missions)))
for i,mission in enumerate(missions):
    ax = axs[i]
    for ob in mission['obs']:
        if ob['source']['type']=='CW':continue
        if ob['assessment'].get('eps',10)>1:continue
        ax.plot(-ob.get('t')*52/constants.year,ob.get('Angular Resolution of t')*1e3,label= ob.get('source').get('label'))
        ax.set_title(mission['label'])
        ax.set_xscale('linear')
        ax.set_yscale('log')
        plt.ylabel('Astrometric Precision [mrad]')
        ax.legend()
        
plt.xlabel('Time to merger [wks]')
plt.subplots_adjust()
